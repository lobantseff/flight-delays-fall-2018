# %% [markdown]
# # [Flight delays](https://www.kaggle.com/c/flight-delays-spring-2018/overview)
# Kaggle InClass competiton by [mlcourse.ai](mlcourse.ai). The task is to predict whether a flight will be delayed for more than 15 minutes

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### Perform dataset preparing

# %%
# pip install nbformat
# execute `output.show()` to show output figures and text (if they are)
# %%capture output  
# %run ./2018-12-12-armavox-prepare-dataset.ipynb

# %% [markdown]
# ### Init required  modules

# %% [markdown]
# __Notebook environment__

# %%
# pip install watermark
# %load_ext watermark
# %watermark -v -m -r -b -g -p numpy,pandas,sklearn,matplotlib,statsmodels,xgboost,catboost
# Out:
# CPython 3.7.1
# IPython 7.2.0
#
# numpy 1.15.4
# pandas 0.23.4
# sklearn 0.20.1
# matplotlib 2.2.2
# statsmodels 0.9.0
# xgboost 0.81
# catboost 0.11.2
#
# compiler   : GCC 7.3.0
# system     : Linux
# release    : 4.14.77-70.59.amzn1.x86_64
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 72
# interpreter: 64bit
# Git hash   : 2a0916569c3397dfd16e42762fdfc89e2ace2fb4
# Git repo   : https://github.com/armavox/flight-delays-spring-2018.git
# Git branch : master

# %%
import numpy as np
import pandas as pd
import itertools
import statsmodels.stats.weightstats as wsts
import scipy.stats as stats
from scipy.sparse import hstack, csr_matrix, issparse

import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['patch.force_edgecolor'] = True

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import (train_test_split, StratifiedKFold, 
                                     cross_val_score, GridSearchCV)
from sklearn.metrics import roc_auc_score

from sklearn.ensemble import RandomForestClassifier

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### IMPORT DATA

# %%
train = pd.read_csv('../data/train.csv', index_col='idx')
train.head(3)
# Out:
#      Month  DayofMonth  DayOfWeek UniqueCarrier Origin Dest  Distance  Hour  \
# idx
# 0        8          21          7            AA    ATL  DFW     732.0    19
# 1        4          20          3            US    PIT  MCO     834.0    15
# 2        9           2          5            XE    RDU  CLE     416.0    14
#
#      Minute  IsWeekend
# idx
# 0        34          1
# 1        48          0
# 2        22          0

# %%
test = pd.read_csv('../data/test.csv', index_col='idx')
test.head(3)
# Out:
#      Month  DayofMonth  DayOfWeek UniqueCarrier Origin Dest  Distance  Hour  \
# idx
# 0        7          25          3            YV    MRY  PHX     598.0     6
# 1        4          17          2            WN    LAS  HOU    1235.0     7
# 2       12           2          7            MQ    GSP  ORD     577.0     6
#
#      Minute  IsWeekend
# idx
# 0        15          0
# 1        39          0
# 2        51          1

# %%
target = pd.read_csv('../data/target.csv', index_col='idx')
target.head(3)
# Out:
#      dep_delayed_15min
# idx
# 0                    0
# 1                    0
# 2                    0

# %% [markdown]
# __Origin_Dest interaction: ``Route`` feature__

# %%
train['Route'] = train['Origin'] + '_' + train['Dest']
test['Route'] = test['Origin'] + '_' + test['Dest']

# %% [markdown]
# ### FEATURES CONVERSION

# %%
train.head(1)
# Out:
#      Month  DayofMonth  DayOfWeek UniqueCarrier Origin Dest  Distance  Hour  \
# idx
# 0        8          21          7            AA    ATL  DFW     732.0    19
#
#      Minute  IsWeekend    Route
# idx
# 0        34          1  ATL_DFW

# %%
ohe = OneHotEncoder(categories='auto', sparse=False, handle_unknown='ignore')

# %%
X_month_train = ohe.fit_transform(train.Month.values.reshape(-1, 1))
X_month_test = ohe.transform(test.Month.values.reshape(-1, 1))

# %%
X_dom_train = ohe.fit_transform(train.DayofMonth.values.reshape(-1, 1))
X_dom_test = ohe.transform(test.DayofMonth.values.reshape(-1, 1))

# %%
X_dow_train = ohe.fit_transform(train.DayOfWeek.values.reshape(-1, 1))
X_dow_test = ohe.transform(test.DayOfWeek.values.reshape(-1, 1))

# %%
X_hour_train = ohe.fit_transform(train.Hour.values.reshape(-1, 1))
X_hour_test = ohe.transform(test.Hour.values.reshape(-1, 1))

# %%
X_minute_train = ohe.fit_transform(train.Minute.values.reshape(-1, 1))
X_minute_test = ohe.transform(test.Minute.values.reshape(-1, 1))

# %%
X_isweekend_train = train.IsWeekend.values.reshape(-1, 1)
X_isweekend_test = test.IsWeekend.values.reshape(-1, 1)

# %%
X_carrier_train = ohe.fit_transform(train.UniqueCarrier.values.reshape(-1, 1))
X_carrier_test = ohe.transform(test.UniqueCarrier.values.reshape(-1, 1))

# %%
X_origin_train = ohe.fit_transform(train.Origin.values.reshape(-1, 1))
X_origin_test = ohe.transform(test.Origin.values.reshape(-1, 1))

# %%
X_dest_train = ohe.fit_transform(train.Dest.values.reshape(-1, 1))
X_dest_test = ohe.transform(test.Dest.values.reshape(-1, 1))

# %%
X_route_train = ohe.fit_transform(train.Route.values.reshape(-1, 1))
X_route_test = ohe.fit_transform(test.Route.values.reshape(-1, 1))

# %% [markdown]
# ### SELECT FEATURES

# %%
def simple_xgb_cv(X, y, n_estimators=27, max_depth=5, seed=42,
                   train_size=0.7):
    """Get ROC-AUC score for simple XGBoost classifier
    """
    skf = StratifiedKFold(n_splits=5, random_state=seed)
    
    X_train, X_valid, y_train, y_valid = train_test_split(
        X, y, train_size=train_size, random_state=seed)

    xgb = XGBClassifier(n_estimators=n_estimators, max_depth=max_depth,
                        random_state=seed, n_jobs=-1).fit(X_train, y_train)
    
    roc_auc = roc_auc_score(y_valid, xgb.predict_proba(X_valid)[:, 1],
                            average='samples')
    
    cv_score = cross_val_score(xgb, X_train, y_train, scoring='roc_auc', 
                               cv=skf, n_jobs=-1)
    return round(roc_auc, 5), round(cv_score.mean(), 5)

# %%
# %%time
features = {'X_month_train': X_month_train, 
            'X_dom_train': X_dom_train, 
            'X_dow_train': X_dow_train, 
            'X_hour_train': X_hour_train, 
            'X_minute_train': X_minute_train,
            'X_isweekend_train': X_isweekend_train,
            'X_carrier_train': X_carrier_train,
            'X_origin_train': X_origin_train,
            'X_dest_train': X_dest_train,
            'X_route_train': X_route_train}

def select_best_feature_comb(features_dict):
    from scipy.sparse import hstack, csr_matrix, isspmatrix_csr
    
    results_dict = {}
    for l in range(1, len(features)+1):

        list_of_keys = [list(comb) for comb in 
                        itertools.combinations(features.keys(), l)]
        list_of_combs = [list(comb) for comb in 
                         itertools.combinations(features.values(), l)]

        for keys, comb in zip(list_of_keys, list_of_combs):
            print('Train on:', keys)
            
            is_csr = [isspmatrix_csr(x) for x in comb]
            if any(is_csr):
                X_con = hstack(comb, format='csr')
            else:
                comb[0] = csr_matrix(comb[0])
                X_con = hstack(comb, format='csr')
                
            result = simple_xgb_cv(X_con, y)
            results_dict[', '.join(keys)] = result
            print(f'CV: {result[1]}, OOF: {result[0]}', '\n')
            
    return results_dict

select_best_feature_comb(features)
# Out:
# Train on: ['X_month_train']
# CV: 0.55243, OOF: 0.5521
#
# Train on: ['X_dom_train']
# CV: 0.52353, OOF: 0.52167
#
# Train on: ['X_dow_train']
# CV: 0.53438, OOF: 0.53991
#
# Train on: ['X_hour_train']
# CV: 0.68467, OOF: 0.68235
#
# Train on: ['X_minute_train']
# CV: 0.52264, OOF: 0.52692
#
# Train on: ['X_isweekend_train']
# CV: 0.50765, OOF: 0.51224
#
# Train on: ['X_carrier_train']
# CV: 0.54553, OOF: 0.54288
#
# Train on: ['X_origin_train']
# CV: 0.54804, OOF: 0.55324
#
# Train on: ['X_dest_train']
# CV: 0.54306, OOF: 0.54792
#
# Train on: ['X_route_train']
# CV: 0.5097, OOF: 0.50741
#
# Train on: ['X_month_train', 'X_dom_train']
# CV: 0.57066, OOF: 0.5735
#
# Train on: ['X_month_train', 'X_dow_train']
# CV: 0.56612, OOF: 0.57273
#
# Train on: ['X_month_train', 'X_hour_train']
# CV: 0.68989, OOF: 0.68917
#
# Train on: ['X_month_train', 'X_minute_train']
# CV: 0.5537, OOF: 0.55604
#
# Train on: ['X_month_train', 'X_isweekend_train']
# CV: 0.55462, OOF: 0.55599
#
# Train on: ['X_month_train', 'X_carrier_train']
# CV: 0.5734, OOF: 0.56957
#
# Train on: ['X_month_train', 'X_origin_train']
# CV: 0.5714, OOF: 0.57262
#
# Train on: ['X_month_train', 'X_dest_train']
# CV: 0.56898, OOF: 0.57086
#
# Train on: ['X_month_train', 'X_route_train']
# CV: 0.557, OOF: 0.55383
#
# Train on: ['X_dom_train', 'X_dow_train']
# CV: 0.55428, OOF: 0.55619
#
# Train on: ['X_dom_train', 'X_hour_train']
# CV: 0.68404, OOF: 0.68163
#
# Train on: ['X_dom_train', 'X_minute_train']
# CV: 0.52722, OOF: 0.53132
#
# Train on: ['X_dom_train', 'X_isweekend_train']
# CV: 0.53133, OOF: 0.52852
#
# Train on: ['X_dom_train', 'X_carrier_train']
# CV: 0.54686, OOF: 0.54446
#
# Train on: ['X_dom_train', 'X_origin_train']
# CV: 0.55285, OOF: 0.55518
#
# Train on: ['X_dom_train', 'X_dest_train']
# CV: 0.54711, OOF: 0.54777
#
# Train on: ['X_dom_train', 'X_route_train']
# CV: 0.52391, OOF: 0.521
#
# Train on: ['X_dow_train', 'X_hour_train']
# CV: 0.68531, OOF: 0.68329
#
# Train on: ['X_dow_train', 'X_minute_train']
# CV: 0.53871, OOF: 0.54454
#
# Train on: ['X_dow_train', 'X_isweekend_train']
# CV: 0.53438, OOF: 0.53991
#
# Train on: ['X_dow_train', 'X_carrier_train']
# CV: 0.55934, OOF: 0.55914
#
# Train on: ['X_dow_train', 'X_origin_train']
# CV: 0.56121, OOF: 0.56724
#
# Train on: ['X_dow_train', 'X_dest_train']
# CV: 0.55788, OOF: 0.56256
#
# Train on: ['X_dow_train', 'X_route_train']
# CV: 0.53905, OOF: 0.54336
#
# Train on: ['X_hour_train', 'X_minute_train']
# CV: 0.68457, OOF: 0.68176
#
# Train on: ['X_hour_train', 'X_isweekend_train']
# CV: 0.68497, OOF: 0.68266
#
# Train on: ['X_hour_train', 'X_carrier_train']
# CV: 0.68832, OOF: 0.68585
#
# Train on: ['X_hour_train', 'X_origin_train']
# CV: 0.68687, OOF: 0.68471
#
# Train on: ['X_hour_train', 'X_dest_train']
# CV: 0.68608, OOF: 0.68441
#
# Train on: ['X_hour_train', 'X_route_train']
# CV: 0.68445, OOF: 0.6827
#
# Train on: ['X_minute_train', 'X_isweekend_train']
# CV: 0.52529, OOF: 0.52739
#
# Train on: ['X_minute_train', 'X_carrier_train']
# CV: 0.5529, OOF: 0.55212
#
# Train on: ['X_minute_train', 'X_origin_train']
# CV: 0.54968, OOF: 0.55791
#
# Train on: ['X_minute_train', 'X_dest_train']
# CV: 0.54573, OOF: 0.54748
#
# Train on: ['X_minute_train', 'X_route_train']
# CV: 0.51932, OOF: 0.52072
#
# Train on: ['X_isweekend_train', 'X_carrier_train']
# CV: 0.54733, OOF: 0.54846
#
# Train on: ['X_isweekend_train', 'X_origin_train']
# CV: 0.54887, OOF: 0.55657
#
# Train on: ['X_isweekend_train', 'X_dest_train']
# CV: 0.54363, OOF: 0.55093
#
# Train on: ['X_isweekend_train', 'X_route_train']
# CV: 0.51638, OOF: 0.5196
#
# Train on: ['X_carrier_train', 'X_origin_train']
# CV: 0.56719, OOF: 0.57169
#
# Train on: ['X_carrier_train', 'X_dest_train']
# CV: 0.56227, OOF: 0.5632
#
# Train on: ['X_carrier_train', 'X_route_train']
# CV: 0.54229, OOF: 0.54437
#
# Train on: ['X_origin_train', 'X_dest_train']
# CV: 0.56388, OOF: 0.56945
#
# Train on: ['X_origin_train', 'X_route_train']
# CV: 0.54495, OOF: 0.55205
#
# Train on: ['X_dest_train', 'X_route_train']
# CV: 0.54455, OOF: 0.54394
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train']
# CV: 0.58188, OOF: 0.58818
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train']
# CV: 0.69067, OOF: 0.68993
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train']
# CV: 0.56797, OOF: 0.57449
#
# Train on: ['X_month_train', 'X_dom_train', 'X_isweekend_train']
# CV: 0.5711, OOF: 0.57364
#
# Train on: ['X_month_train', 'X_dom_train', 'X_carrier_train']
# CV: 0.57834, OOF: 0.57736
#
# Train on: ['X_month_train', 'X_dom_train', 'X_origin_train']
# CV: 0.57878, OOF: 0.58132
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dest_train']
# CV: 0.5774, OOF: 0.58036
#
# Train on: ['X_month_train', 'X_dom_train', 'X_route_train']
# CV: 0.56709, OOF: 0.56656
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train']
# CV: 0.69025, OOF: 0.68962
#
# Train on: ['X_month_train', 'X_dow_train', 'X_minute_train']
# CV: 0.56719, OOF: 0.57178
#
# Train on: ['X_month_train', 'X_dow_train', 'X_isweekend_train']
# CV: 0.56603, OOF: 0.57326
#
# Train on: ['X_month_train', 'X_dow_train', 'X_carrier_train']
# CV: 0.58551, OOF: 0.58583
#
# Train on: ['X_month_train', 'X_dow_train', 'X_origin_train']
# CV: 0.58255, OOF: 0.58596
#
# Train on: ['X_month_train', 'X_dow_train', 'X_dest_train']
# CV: 0.5794, OOF: 0.58491
#
# Train on: ['X_month_train', 'X_dow_train', 'X_route_train']
# CV: 0.56881, OOF: 0.57261
#
# Train on: ['X_month_train', 'X_hour_train', 'X_minute_train']
# CV: 0.68999, OOF: 0.68874
#
# Train on: ['X_month_train', 'X_hour_train', 'X_isweekend_train']
# CV: 0.68912, OOF: 0.68933
#
# Train on: ['X_month_train', 'X_hour_train', 'X_carrier_train']
# CV: 0.69269, OOF: 0.69284
#
# Train on: ['X_month_train', 'X_hour_train', 'X_origin_train']
# CV: 0.69242, OOF: 0.69039
#
# Train on: ['X_month_train', 'X_hour_train', 'X_dest_train']
# CV: 0.69109, OOF: 0.68892
#
# Train on: ['X_month_train', 'X_hour_train', 'X_route_train']
# CV: 0.69026, OOF: 0.68945
#
# Train on: ['X_month_train', 'X_minute_train', 'X_isweekend_train']
# CV: 0.5552, OOF: 0.55782
#
# Train on: ['X_month_train', 'X_minute_train', 'X_carrier_train']
# CV: 0.57555, OOF: 0.57287
#
# Train on: ['X_month_train', 'X_minute_train', 'X_origin_train']
# CV: 0.57138, OOF: 0.57222
#
# Train on: ['X_month_train', 'X_minute_train', 'X_dest_train']
# CV: 0.57005, OOF: 0.5739
#
# Train on: ['X_month_train', 'X_minute_train', 'X_route_train']
# CV: 0.5573, OOF: 0.55609
#
# Train on: ['X_month_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.57412, OOF: 0.57204
#
# Train on: ['X_month_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.57168, OOF: 0.574
#
# Train on: ['X_month_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.57, OOF: 0.57122
#
# Train on: ['X_month_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.55767, OOF: 0.5551
#
# Train on: ['X_month_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.58392, OOF: 0.58687
#
# Train on: ['X_month_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.58201, OOF: 0.58019
#
# Train on: ['X_month_train', 'X_carrier_train', 'X_route_train']
# CV: 0.57294, OOF: 0.56729
#
# Train on: ['X_month_train', 'X_origin_train', 'X_dest_train']
# CV: 0.58149, OOF: 0.58307
#
# Train on: ['X_month_train', 'X_origin_train', 'X_route_train']
# CV: 0.5689, OOF: 0.57042
#
# Train on: ['X_month_train', 'X_dest_train', 'X_route_train']
# CV: 0.56983, OOF: 0.57066
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_hour_train']
# CV: 0.68554, OOF: 0.68303
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_minute_train']
# CV: 0.55122, OOF: 0.55678
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_isweekend_train']
# CV: 0.55472, OOF: 0.55636
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_carrier_train']
# CV: 0.56605, OOF: 0.56704
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_origin_train']
# CV: 0.56644, OOF: 0.57084
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_dest_train']
# CV: 0.56313, OOF: 0.57176
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_route_train']
# CV: 0.55127, OOF: 0.55811
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_minute_train']
# CV: 0.68453, OOF: 0.68192
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_isweekend_train']
# CV: 0.6841, OOF: 0.68175
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_carrier_train']
# CV: 0.68842, OOF: 0.68586
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_origin_train']
# CV: 0.68685, OOF: 0.68473
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_dest_train']
# CV: 0.68604, OOF: 0.68456
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_route_train']
# CV: 0.68427, OOF: 0.68263
#
# Train on: ['X_dom_train', 'X_minute_train', 'X_isweekend_train']
# CV: 0.53193, OOF: 0.53579
#
# Train on: ['X_dom_train', 'X_minute_train', 'X_carrier_train']
# CV: 0.55224, OOF: 0.55165
#
# Train on: ['X_dom_train', 'X_minute_train', 'X_origin_train']
# CV: 0.55583, OOF: 0.55908
#
# Train on: ['X_dom_train', 'X_minute_train', 'X_dest_train']
# CV: 0.54802, OOF: 0.55253
#
# Train on: ['X_dom_train', 'X_minute_train', 'X_route_train']
# CV: 0.52819, OOF: 0.53182
#
# Train on: ['X_dom_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.54898, OOF: 0.55237
#
# Train on: ['X_dom_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.55625, OOF: 0.55808
#
# Train on: ['X_dom_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.55016, OOF: 0.55029
#
# Train on: ['X_dom_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.5305, OOF: 0.53136
#
# Train on: ['X_dom_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.56726, OOF: 0.57053
#
# Train on: ['X_dom_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.56337, OOF: 0.56045
#
# Train on: ['X_dom_train', 'X_carrier_train', 'X_route_train']
# CV: 0.54544, OOF: 0.54807
#
# Train on: ['X_dom_train', 'X_origin_train', 'X_dest_train']
# CV: 0.56709, OOF: 0.57149
#
# Train on: ['X_dom_train', 'X_origin_train', 'X_route_train']
# CV: 0.55164, OOF: 0.55086
#
# Train on: ['X_dom_train', 'X_dest_train', 'X_route_train']
# CV: 0.54838, OOF: 0.54804
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_minute_train']
# CV: 0.68595, OOF: 0.68542
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_isweekend_train']
# CV: 0.68529, OOF: 0.68311
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_carrier_train']
# CV: 0.68958, OOF: 0.68883
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_origin_train']
# CV: 0.68853, OOF: 0.68774
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_dest_train']
# CV: 0.6886, OOF: 0.68739
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_route_train']
# CV: 0.68556, OOF: 0.68324
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_isweekend_train']
# CV: 0.53864, OOF: 0.54455
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_carrier_train']
# CV: 0.56297, OOF: 0.56132
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_origin_train']
# CV: 0.56037, OOF: 0.56722
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_dest_train']
# CV: 0.55813, OOF: 0.56361
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_route_train']
# CV: 0.54059, OOF: 0.54491
#
# Train on: ['X_dow_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.55908, OOF: 0.55946
#
# Train on: ['X_dow_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.56102, OOF: 0.56562
#
# Train on: ['X_dow_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.55735, OOF: 0.56253
#
# Train on: ['X_dow_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.53917, OOF: 0.54357
#
# Train on: ['X_dow_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.57373, OOF: 0.58
#
# Train on: ['X_dow_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.57369, OOF: 0.57086
#
# Train on: ['X_dow_train', 'X_carrier_train', 'X_route_train']
# CV: 0.56072, OOF: 0.55914
#
# Train on: ['X_dow_train', 'X_origin_train', 'X_dest_train']
# CV: 0.57411, OOF: 0.58059
#
# Train on: ['X_dow_train', 'X_origin_train', 'X_route_train']
# CV: 0.56005, OOF: 0.56556
#
# Train on: ['X_dow_train', 'X_dest_train', 'X_route_train']
# CV: 0.5595, OOF: 0.5632
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_isweekend_train']
# CV: 0.68434, OOF: 0.68186
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_carrier_train']
# CV: 0.68825, OOF: 0.68616
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_origin_train']
# CV: 0.68689, OOF: 0.68488
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_dest_train']
# CV: 0.68603, OOF: 0.68481
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_route_train']
# CV: 0.6847, OOF: 0.6821
#
# Train on: ['X_hour_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.68835, OOF: 0.68591
#
# Train on: ['X_hour_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.68693, OOF: 0.68476
#
# Train on: ['X_hour_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.68597, OOF: 0.68452
#
# Train on: ['X_hour_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.68441, OOF: 0.68292
#
# Train on: ['X_hour_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.68957, OOF: 0.68835
#
# Train on: ['X_hour_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.68908, OOF: 0.68748
#
# Train on: ['X_hour_train', 'X_carrier_train', 'X_route_train']
# CV: 0.68786, OOF: 0.68595
#
# Train on: ['X_hour_train', 'X_origin_train', 'X_dest_train']
# CV: 0.68747, OOF: 0.68507
#
# Train on: ['X_hour_train', 'X_origin_train', 'X_route_train']
# CV: 0.68694, OOF: 0.68449
#
# Train on: ['X_hour_train', 'X_dest_train', 'X_route_train']
# CV: 0.68586, OOF: 0.68462
#
# Train on: ['X_minute_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.55343, OOF: 0.55458
#
# Train on: ['X_minute_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.5527, OOF: 0.56082
#
# Train on: ['X_minute_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.54702, OOF: 0.55181
#
# Train on: ['X_minute_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.5241, OOF: 0.52797
#
# Train on: ['X_minute_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.56988, OOF: 0.574
#
# Train on: ['X_minute_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.56405, OOF: 0.56329
#
# Train on: ['X_minute_train', 'X_carrier_train', 'X_route_train']
# CV: 0.55002, OOF: 0.55002
#
# Train on: ['X_minute_train', 'X_origin_train', 'X_dest_train']
# CV: 0.56457, OOF: 0.57106
#
# Train on: ['X_minute_train', 'X_origin_train', 'X_route_train']
# CV: 0.54728, OOF: 0.55755
#
# Train on: ['X_minute_train', 'X_dest_train', 'X_route_train']
# CV: 0.54522, OOF: 0.5496
#
# Train on: ['X_isweekend_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.56834, OOF: 0.57787
#
# Train on: ['X_isweekend_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.5643, OOF: 0.56123
#
# Train on: ['X_isweekend_train', 'X_carrier_train', 'X_route_train']
# CV: 0.54754, OOF: 0.5486
#
# Train on: ['X_isweekend_train', 'X_origin_train', 'X_dest_train']
# CV: 0.5654, OOF: 0.57003
#
# Train on: ['X_isweekend_train', 'X_origin_train', 'X_route_train']
# CV: 0.54717, OOF: 0.55822
#
# Train on: ['X_isweekend_train', 'X_dest_train', 'X_route_train']
# CV: 0.54566, OOF: 0.54965
#
# Train on: ['X_carrier_train', 'X_origin_train', 'X_dest_train']
# CV: 0.57907, OOF: 0.5827
#
# Train on: ['X_carrier_train', 'X_origin_train', 'X_route_train']
# CV: 0.5663, OOF: 0.57053
#
# Train on: ['X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.56305, OOF: 0.55882
#
# Train on: ['X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.56411, OOF: 0.56817
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train']
# CV: 0.69036, OOF: 0.69037
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_minute_train']
# CV: 0.57955, OOF: 0.58526
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_isweekend_train']
# CV: 0.58133, OOF: 0.58697
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_carrier_train']
# CV: 0.58928, OOF: 0.5926
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_origin_train']
# CV: 0.58883, OOF: 0.59458
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_dest_train']
# CV: 0.58676, OOF: 0.59455
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_route_train']
# CV: 0.57955, OOF: 0.58573
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_minute_train']
# CV: 0.69062, OOF: 0.68742
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_isweekend_train']
# CV: 0.69058, OOF: 0.68962
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_carrier_train']
# CV: 0.6927, OOF: 0.69235
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_origin_train']
# CV: 0.69269, OOF: 0.69107
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_dest_train']
# CV: 0.6916, OOF: 0.692
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_route_train']
# CV: 0.68883, OOF: 0.68996
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train', 'X_isweekend_train']
# CV: 0.5678, OOF: 0.57475
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train', 'X_carrier_train']
# CV: 0.58154, OOF: 0.57901
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train', 'X_origin_train']
# CV: 0.57892, OOF: 0.58181
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train', 'X_dest_train']
# CV: 0.5769, OOF: 0.58115
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train', 'X_route_train']
# CV: 0.56683, OOF: 0.56899
#
# Train on: ['X_month_train', 'X_dom_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.57824, OOF: 0.57834
#
# Train on: ['X_month_train', 'X_dom_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.57902, OOF: 0.58144
#
# Train on: ['X_month_train', 'X_dom_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.57678, OOF: 0.58175
#
# Train on: ['X_month_train', 'X_dom_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.567, OOF: 0.56867
#
# Train on: ['X_month_train', 'X_dom_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.588, OOF: 0.59089
#
# Train on: ['X_month_train', 'X_dom_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.58601, OOF: 0.58416
#
# Train on: ['X_month_train', 'X_dom_train', 'X_carrier_train', 'X_route_train']
# CV: 0.57693, OOF: 0.57264
#
# Train on: ['X_month_train', 'X_dom_train', 'X_origin_train', 'X_dest_train']
# CV: 0.58677, OOF: 0.59226
#
# Train on: ['X_month_train', 'X_dom_train', 'X_origin_train', 'X_route_train']
# CV: 0.57795, OOF: 0.57903
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dest_train', 'X_route_train']
# CV: 0.57585, OOF: 0.58211
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_minute_train']
# CV: 0.6908, OOF: 0.68962
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_isweekend_train']
# CV: 0.69025, OOF: 0.68965
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_carrier_train']
# CV: 0.69358, OOF: 0.69244
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_origin_train']
# CV: 0.69375, OOF: 0.69126
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_dest_train']
# CV: 0.69135, OOF: 0.69077
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_route_train']
# CV: 0.69017, OOF: 0.68806
#
# Train on: ['X_month_train', 'X_dow_train', 'X_minute_train', 'X_isweekend_train']
# CV: 0.56723, OOF: 0.57262
#
# Train on: ['X_month_train', 'X_dow_train', 'X_minute_train', 'X_carrier_train']
# CV: 0.58648, OOF: 0.58675
#
# Train on: ['X_month_train', 'X_dow_train', 'X_minute_train', 'X_origin_train']
# CV: 0.58156, OOF: 0.58671
#
# Train on: ['X_month_train', 'X_dow_train', 'X_minute_train', 'X_dest_train']
# CV: 0.57935, OOF: 0.58347
#
# Train on: ['X_month_train', 'X_dow_train', 'X_minute_train', 'X_route_train']
# CV: 0.56918, OOF: 0.573
#
# Train on: ['X_month_train', 'X_dow_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.5846, OOF: 0.58495
#
# Train on: ['X_month_train', 'X_dow_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.58238, OOF: 0.5859
#
# Train on: ['X_month_train', 'X_dow_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.57901, OOF: 0.58528
#
# Train on: ['X_month_train', 'X_dow_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.56937, OOF: 0.57341
#
# Train on: ['X_month_train', 'X_dow_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.59429, OOF: 0.59925
#
# Train on: ['X_month_train', 'X_dow_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.59325, OOF: 0.59224
#
# Train on: ['X_month_train', 'X_dow_train', 'X_carrier_train', 'X_route_train']
# CV: 0.58455, OOF: 0.5835
#
# Train on: ['X_month_train', 'X_dow_train', 'X_origin_train', 'X_dest_train']
# CV: 0.5907, OOF: 0.59573
#
# Train on: ['X_month_train', 'X_dow_train', 'X_origin_train', 'X_route_train']
# CV: 0.58072, OOF: 0.58635
#
# Train on: ['X_month_train', 'X_dow_train', 'X_dest_train', 'X_route_train']
# CV: 0.58087, OOF: 0.58478
#
# Train on: ['X_month_train', 'X_hour_train', 'X_minute_train', 'X_isweekend_train']
# CV: 0.69, OOF: 0.68876
#
# Train on: ['X_month_train', 'X_hour_train', 'X_minute_train', 'X_carrier_train']
# CV: 0.69298, OOF: 0.69278
#
# Train on: ['X_month_train', 'X_hour_train', 'X_minute_train', 'X_origin_train']
# CV: 0.69279, OOF: 0.69032
#
# Train on: ['X_month_train', 'X_hour_train', 'X_minute_train', 'X_dest_train']
# CV: 0.69137, OOF: 0.69123
#
# Train on: ['X_month_train', 'X_hour_train', 'X_minute_train', 'X_route_train']
# CV: 0.68915, OOF: 0.68926
#
# Train on: ['X_month_train', 'X_hour_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.69268, OOF: 0.69269
#
# Train on: ['X_month_train', 'X_hour_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.69243, OOF: 0.69036
#
# Train on: ['X_month_train', 'X_hour_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.69105, OOF: 0.6889
#
# Train on: ['X_month_train', 'X_hour_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.69006, OOF: 0.68946
#
# Train on: ['X_month_train', 'X_hour_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.69409, OOF: 0.6946
#
# Train on: ['X_month_train', 'X_hour_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.69479, OOF: 0.69375
#
# Train on: ['X_month_train', 'X_hour_train', 'X_carrier_train', 'X_route_train']
# CV: 0.69381, OOF: 0.69269
#
# Train on: ['X_month_train', 'X_hour_train', 'X_origin_train', 'X_dest_train']
# CV: 0.69309, OOF: 0.69138
#
# Train on: ['X_month_train', 'X_hour_train', 'X_origin_train', 'X_route_train']
# CV: 0.69335, OOF: 0.69074
#
# Train on: ['X_month_train', 'X_hour_train', 'X_dest_train', 'X_route_train']
# CV: 0.69076, OOF: 0.69109
#
# Train on: ['X_month_train', 'X_minute_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.57701, OOF: 0.57574
#
# Train on: ['X_month_train', 'X_minute_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.57194, OOF: 0.57545
#
# Train on: ['X_month_train', 'X_minute_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.57097, OOF: 0.57336
#
# Train on: ['X_month_train', 'X_minute_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.55784, OOF: 0.55755
#
# Train on: ['X_month_train', 'X_minute_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.58553, OOF: 0.58743
#
# Train on: ['X_month_train', 'X_minute_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.58349, OOF: 0.57988
#
# Train on: ['X_month_train', 'X_minute_train', 'X_carrier_train', 'X_route_train']
# CV: 0.57549, OOF: 0.57088
#
# Train on: ['X_month_train', 'X_minute_train', 'X_origin_train', 'X_dest_train']
# CV: 0.58125, OOF: 0.58585
#
# Train on: ['X_month_train', 'X_minute_train', 'X_origin_train', 'X_route_train']
# CV: 0.57083, OOF: 0.57076
#
# Train on: ['X_month_train', 'X_minute_train', 'X_dest_train', 'X_route_train']
# CV: 0.57041, OOF: 0.5722
#
# Train on: ['X_month_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.58375, OOF: 0.58696
#
# Train on: ['X_month_train', 'X_isweekend_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.58252, OOF: 0.58045
#
# Train on: ['X_month_train', 'X_isweekend_train', 'X_carrier_train', 'X_route_train']
# CV: 0.57332, OOF: 0.56851
#
# Train on: ['X_month_train', 'X_isweekend_train', 'X_origin_train', 'X_dest_train']
# CV: 0.5812, OOF: 0.58467
#
# Train on: ['X_month_train', 'X_isweekend_train', 'X_origin_train', 'X_route_train']
# CV: 0.56949, OOF: 0.5707
#
# Train on: ['X_month_train', 'X_isweekend_train', 'X_dest_train', 'X_route_train']
# CV: 0.57079, OOF: 0.57194
#
# Train on: ['X_month_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train']
# CV: 0.59084, OOF: 0.59374
#
# Train on: ['X_month_train', 'X_carrier_train', 'X_origin_train', 'X_route_train']
# CV: 0.58278, OOF: 0.58489
#
# Train on: ['X_month_train', 'X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.58215, OOF: 0.57784
#
# Train on: ['X_month_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.58127, OOF: 0.58266
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_hour_train', 'X_minute_train']
# CV: 0.68594, OOF: 0.68299
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_hour_train', 'X_isweekend_train']
# CV: 0.68558, OOF: 0.68319
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_hour_train', 'X_carrier_train']
# CV: 0.69044, OOF: 0.68915
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_hour_train', 'X_origin_train']
# CV: 0.68867, OOF: 0.68782
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_hour_train', 'X_dest_train']
# CV: 0.68953, OOF: 0.68733
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_hour_train', 'X_route_train']
# CV: 0.68592, OOF: 0.6833
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_minute_train', 'X_isweekend_train']
# CV: 0.55023, OOF: 0.55773
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_minute_train', 'X_carrier_train']
# CV: 0.56725, OOF: 0.57036
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_minute_train', 'X_origin_train']
# CV: 0.56658, OOF: 0.57218
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_minute_train', 'X_dest_train']
# CV: 0.56252, OOF: 0.57023
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_minute_train', 'X_route_train']
# CV: 0.55069, OOF: 0.55729
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.56592, OOF: 0.5663
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.56766, OOF: 0.57229
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.56267, OOF: 0.57191
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.55029, OOF: 0.55947
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.57667, OOF: 0.58286
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.5765, OOF: 0.57552
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_carrier_train', 'X_route_train']
# CV: 0.56479, OOF: 0.56651
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_origin_train', 'X_dest_train']
# CV: 0.57713, OOF: 0.58531
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_origin_train', 'X_route_train']
# CV: 0.56555, OOF: 0.57121
#
# Train on: ['X_dom_train', 'X_dow_train', 'X_dest_train', 'X_route_train']
# CV: 0.56427, OOF: 0.57197
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_minute_train', 'X_isweekend_train']
# CV: 0.68416, OOF: 0.68218
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_minute_train', 'X_carrier_train']
# CV: 0.68819, OOF: 0.68599
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_minute_train', 'X_origin_train']
# CV: 0.68688, OOF: 0.68481
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_minute_train', 'X_dest_train']
# CV: 0.68636, OOF: 0.68483
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_minute_train', 'X_route_train']
# CV: 0.68463, OOF: 0.68245
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.68836, OOF: 0.68606
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.68696, OOF: 0.68476
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.68598, OOF: 0.68457
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.68425, OOF: 0.68271
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.68897, OOF: 0.68839
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.68916, OOF: 0.68758
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_carrier_train', 'X_route_train']
# CV: 0.68796, OOF: 0.68553
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_origin_train', 'X_dest_train']
# CV: 0.68747, OOF: 0.6851
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_origin_train', 'X_route_train']
# CV: 0.68697, OOF: 0.68462
#
# Train on: ['X_dom_train', 'X_hour_train', 'X_dest_train', 'X_route_train']
# CV: 0.68578, OOF: 0.6846
#
# Train on: ['X_dom_train', 'X_minute_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.55401, OOF: 0.55634
#
# Train on: ['X_dom_train', 'X_minute_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.55842, OOF: 0.56434
#
# Train on: ['X_dom_train', 'X_minute_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.55047, OOF: 0.55668
#
# Train on: ['X_dom_train', 'X_minute_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.53418, OOF: 0.53681
#
# Train on: ['X_dom_train', 'X_minute_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.57029, OOF: 0.57485
#
# Train on: ['X_dom_train', 'X_minute_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.56611, OOF: 0.56493
#
# Train on: ['X_dom_train', 'X_minute_train', 'X_carrier_train', 'X_route_train']
# CV: 0.55096, OOF: 0.55274
#
# Train on: ['X_dom_train', 'X_minute_train', 'X_origin_train', 'X_dest_train']
# CV: 0.56711, OOF: 0.57265
#
# Train on: ['X_dom_train', 'X_minute_train', 'X_origin_train', 'X_route_train']
# CV: 0.55236, OOF: 0.55629
#
# Train on: ['X_dom_train', 'X_minute_train', 'X_dest_train', 'X_route_train']
# CV: 0.55065, OOF: 0.55364
#
# Train on: ['X_dom_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.5683, OOF: 0.575
#
# Train on: ['X_dom_train', 'X_isweekend_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.56487, OOF: 0.56042
#
# Train on: ['X_dom_train', 'X_isweekend_train', 'X_carrier_train', 'X_route_train']
# CV: 0.54831, OOF: 0.55306
#
# Train on: ['X_dom_train', 'X_isweekend_train', 'X_origin_train', 'X_dest_train']
# CV: 0.56729, OOF: 0.57251
#
# Train on: ['X_dom_train', 'X_isweekend_train', 'X_origin_train', 'X_route_train']
# CV: 0.55569, OOF: 0.55842
#
# Train on: ['X_dom_train', 'X_isweekend_train', 'X_dest_train', 'X_route_train']
# CV: 0.54991, OOF: 0.55505
#
# Train on: ['X_dom_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train']
# CV: 0.57989, OOF: 0.5831
#
# Train on: ['X_dom_train', 'X_carrier_train', 'X_origin_train', 'X_route_train']
# CV: 0.56724, OOF: 0.57178
#
# Train on: ['X_dom_train', 'X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.56417, OOF: 0.56134
#
# Train on: ['X_dom_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.56639, OOF: 0.57196
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_minute_train', 'X_isweekend_train']
# CV: 0.68594, OOF: 0.68271
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_minute_train', 'X_carrier_train']
# CV: 0.68937, OOF: 0.68899
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_minute_train', 'X_origin_train']
# CV: 0.68858, OOF: 0.68787
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_minute_train', 'X_dest_train']
# CV: 0.68822, OOF: 0.68748
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_minute_train', 'X_route_train']
# CV: 0.68672, OOF: 0.68314
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.68962, OOF: 0.68882
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.68849, OOF: 0.68788
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.68857, OOF: 0.6874
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.68553, OOF: 0.68324
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.69181, OOF: 0.6913
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.6917, OOF: 0.69079
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_carrier_train', 'X_route_train']
# CV: 0.68885, OOF: 0.68905
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_origin_train', 'X_dest_train']
# CV: 0.69096, OOF: 0.68546
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_origin_train', 'X_route_train']
# CV: 0.68941, OOF: 0.68772
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_dest_train', 'X_route_train']
# CV: 0.68833, OOF: 0.68716
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.56326, OOF: 0.56211
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.5609, OOF: 0.56692
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.55798, OOF: 0.56369
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.54083, OOF: 0.54665
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.57477, OOF: 0.58131
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.57506, OOF: 0.57087
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_carrier_train', 'X_route_train']
# CV: 0.56361, OOF: 0.56247
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_origin_train', 'X_dest_train']
# CV: 0.57363, OOF: 0.58062
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_origin_train', 'X_route_train']
# CV: 0.5608, OOF: 0.56633
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_dest_train', 'X_route_train']
# CV: 0.55999, OOF: 0.5648
#
# Train on: ['X_dow_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.57428, OOF: 0.57814
#
# Train on: ['X_dow_train', 'X_isweekend_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.5735, OOF: 0.57024
#
# Train on: ['X_dow_train', 'X_isweekend_train', 'X_carrier_train', 'X_route_train']
# CV: 0.56141, OOF: 0.55981
#
# Train on: ['X_dow_train', 'X_isweekend_train', 'X_origin_train', 'X_dest_train']
# CV: 0.57471, OOF: 0.58055
#
# Train on: ['X_dow_train', 'X_isweekend_train', 'X_origin_train', 'X_route_train']
# CV: 0.55992, OOF: 0.5656
#
# Train on: ['X_dow_train', 'X_isweekend_train', 'X_dest_train', 'X_route_train']
# CV: 0.5595, OOF: 0.56325
#
# Train on: ['X_dow_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train']
# CV: 0.58491, OOF: 0.58941
#
# Train on: ['X_dow_train', 'X_carrier_train', 'X_origin_train', 'X_route_train']
# CV: 0.57266, OOF: 0.57813
#
# Train on: ['X_dow_train', 'X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.57376, OOF: 0.57365
#
# Train on: ['X_dow_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.57442, OOF: 0.58031
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.68819, OOF: 0.68618
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.68684, OOF: 0.68481
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.68597, OOF: 0.6848
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.68442, OOF: 0.68239
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.69015, OOF: 0.68836
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.68905, OOF: 0.68782
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_carrier_train', 'X_route_train']
# CV: 0.68777, OOF: 0.68615
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_origin_train', 'X_dest_train']
# CV: 0.68753, OOF: 0.68517
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_origin_train', 'X_route_train']
# CV: 0.68696, OOF: 0.68445
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_dest_train', 'X_route_train']
# CV: 0.68588, OOF: 0.68474
#
# Train on: ['X_hour_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.68961, OOF: 0.68846
#
# Train on: ['X_hour_train', 'X_isweekend_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.68908, OOF: 0.68751
#
# Train on: ['X_hour_train', 'X_isweekend_train', 'X_carrier_train', 'X_route_train']
# CV: 0.68774, OOF: 0.68614
#
# Train on: ['X_hour_train', 'X_isweekend_train', 'X_origin_train', 'X_dest_train']
# CV: 0.68744, OOF: 0.68524
#
# Train on: ['X_hour_train', 'X_isweekend_train', 'X_origin_train', 'X_route_train']
# CV: 0.68686, OOF: 0.68448
#
# Train on: ['X_hour_train', 'X_isweekend_train', 'X_dest_train', 'X_route_train']
# CV: 0.68583, OOF: 0.68447
#
# Train on: ['X_hour_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train']
# CV: 0.69199, OOF: 0.68865
#
# Train on: ['X_hour_train', 'X_carrier_train', 'X_origin_train', 'X_route_train']
# CV: 0.68886, OOF: 0.68861
#
# Train on: ['X_hour_train', 'X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.68856, OOF: 0.68744
#
# Train on: ['X_hour_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.68742, OOF: 0.68507
#
# Train on: ['X_minute_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.57047, OOF: 0.57702
#
# Train on: ['X_minute_train', 'X_isweekend_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.56437, OOF: 0.565
#
# Train on: ['X_minute_train', 'X_isweekend_train', 'X_carrier_train', 'X_route_train']
# CV: 0.55165, OOF: 0.55175
#
# Train on: ['X_minute_train', 'X_isweekend_train', 'X_origin_train', 'X_dest_train']
# CV: 0.56645, OOF: 0.57105
#
# Train on: ['X_minute_train', 'X_isweekend_train', 'X_origin_train', 'X_route_train']
# CV: 0.54867, OOF: 0.55855
#
# Train on: ['X_minute_train', 'X_isweekend_train', 'X_dest_train', 'X_route_train']
# CV: 0.54783, OOF: 0.5537
#
# Train on: ['X_minute_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train']
# CV: 0.58062, OOF: 0.58321
#
# Train on: ['X_minute_train', 'X_carrier_train', 'X_origin_train', 'X_route_train']
# CV: 0.56897, OOF: 0.57245
#
# Train on: ['X_minute_train', 'X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.5652, OOF: 0.56541
#
# Train on: ['X_minute_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.56522, OOF: 0.57117
#
# Train on: ['X_isweekend_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train']
# CV: 0.5799, OOF: 0.58287
#
# Train on: ['X_isweekend_train', 'X_carrier_train', 'X_origin_train', 'X_route_train']
# CV: 0.56718, OOF: 0.56995
#
# Train on: ['X_isweekend_train', 'X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.56322, OOF: 0.56425
#
# Train on: ['X_isweekend_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.56372, OOF: 0.56881
#
# Train on: ['X_carrier_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.57915, OOF: 0.58323
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_minute_train']
# CV: 0.6911, OOF: 0.68807
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_isweekend_train']
# CV: 0.69051, OOF: 0.69044
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_carrier_train']
# CV: 0.69446, OOF: 0.69508
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_origin_train']
# CV: 0.69305, OOF: 0.69345
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_dest_train']
# CV: 0.69248, OOF: 0.69133
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_route_train']
# CV: 0.69064, OOF: 0.69071
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_minute_train', 'X_isweekend_train']
# CV: 0.57999, OOF: 0.58509
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_minute_train', 'X_carrier_train']
# CV: 0.59119, OOF: 0.59439
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_minute_train', 'X_origin_train']
# CV: 0.58874, OOF: 0.59553
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_minute_train', 'X_dest_train']
# CV: 0.58801, OOF: 0.59252
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_minute_train', 'X_route_train']
# CV: 0.57899, OOF: 0.58351
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.59024, OOF: 0.59258
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.58849, OOF: 0.59471
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.58676, OOF: 0.59506
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.57991, OOF: 0.58564
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.59673, OOF: 0.60268
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.5966, OOF: 0.59961
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_carrier_train', 'X_route_train']
# CV: 0.58976, OOF: 0.5917
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_origin_train', 'X_dest_train']
# CV: 0.59399, OOF: 0.60346
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_origin_train', 'X_route_train']
# CV: 0.5879, OOF: 0.59473
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_dest_train', 'X_route_train']
# CV: 0.58752, OOF: 0.59528
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_minute_train', 'X_isweekend_train']
# CV: 0.69039, OOF: 0.68748
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_minute_train', 'X_carrier_train']
# CV: 0.69357, OOF: 0.69222
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_minute_train', 'X_origin_train']
# CV: 0.69261, OOF: 0.69116
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_minute_train', 'X_dest_train']
# CV: 0.69175, OOF: 0.69195
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_minute_train', 'X_route_train']
# CV: 0.69012, OOF: 0.69016
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.6925, OOF: 0.69237
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.69277, OOF: 0.69085
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.69107, OOF: 0.69199
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.68988, OOF: 0.68997
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.69439, OOF: 0.69422
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.6955, OOF: 0.69451
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_carrier_train', 'X_route_train']
# CV: 0.69422, OOF: 0.69247
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_origin_train', 'X_dest_train']
# CV: 0.6933, OOF: 0.6921
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_origin_train', 'X_route_train']
# CV: 0.69293, OOF: 0.69178
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_dest_train', 'X_route_train']
# CV: 0.69214, OOF: 0.69205
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.58088, OOF: 0.58152
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.57857, OOF: 0.58149
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.57671, OOF: 0.5824
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.56617, OOF: 0.5706
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.58956, OOF: 0.59259
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.58841, OOF: 0.58858
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train', 'X_carrier_train', 'X_route_train']
# CV: 0.58046, OOF: 0.57825
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train', 'X_origin_train', 'X_dest_train']
# CV: 0.58751, OOF: 0.59094
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train', 'X_origin_train', 'X_route_train']
# CV: 0.57815, OOF: 0.57906
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train', 'X_dest_train', 'X_route_train']
# CV: 0.57719, OOF: 0.58229
#
# Train on: ['X_month_train', 'X_dom_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.58695, OOF: 0.59183
#
# Train on: ['X_month_train', 'X_dom_train', 'X_isweekend_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.58558, OOF: 0.58389
#
# Train on: ['X_month_train', 'X_dom_train', 'X_isweekend_train', 'X_carrier_train', 'X_route_train']
# CV: 0.5771, OOF: 0.57365
#
# Train on: ['X_month_train', 'X_dom_train', 'X_isweekend_train', 'X_origin_train', 'X_dest_train']
# CV: 0.58749, OOF: 0.59162
#
# Train on: ['X_month_train', 'X_dom_train', 'X_isweekend_train', 'X_origin_train', 'X_route_train']
# CV: 0.57677, OOF: 0.57969
#
# Train on: ['X_month_train', 'X_dom_train', 'X_isweekend_train', 'X_dest_train', 'X_route_train']
# CV: 0.57719, OOF: 0.58121
#
# Train on: ['X_month_train', 'X_dom_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train']
# CV: 0.59528, OOF: 0.59814
#
# Train on: ['X_month_train', 'X_dom_train', 'X_carrier_train', 'X_origin_train', 'X_route_train']
# CV: 0.58747, OOF: 0.58905
#
# Train on: ['X_month_train', 'X_dom_train', 'X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.58679, OOF: 0.58417
#
# Train on: ['X_month_train', 'X_dom_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.58704, OOF: 0.59297
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_minute_train', 'X_isweekend_train']
# CV: 0.69076, OOF: 0.68978
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_minute_train', 'X_carrier_train']
# CV: 0.69383, OOF: 0.69259
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_minute_train', 'X_origin_train']
# CV: 0.69416, OOF: 0.69128
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_minute_train', 'X_dest_train']
# CV: 0.69197, OOF: 0.69069
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_minute_train', 'X_route_train']
# CV: 0.6902, OOF: 0.69014
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.69342, OOF: 0.69244
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.69333, OOF: 0.69124
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.69132, OOF: 0.69074
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.69016, OOF: 0.68808
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.69498, OOF: 0.69392
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.69606, OOF: 0.69403
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_carrier_train', 'X_route_train']
# CV: 0.6942, OOF: 0.69234
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_origin_train', 'X_dest_train']
# CV: 0.69374, OOF: 0.69156
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_origin_train', 'X_route_train']
# CV: 0.69308, OOF: 0.69091
#
# Train on: ['X_month_train', 'X_dow_train', 'X_hour_train', 'X_dest_train', 'X_route_train']
# CV: 0.69283, OOF: 0.69054
#
# Train on: ['X_month_train', 'X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.58588, OOF: 0.58691
#
# Train on: ['X_month_train', 'X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.58163, OOF: 0.58673
#
# Train on: ['X_month_train', 'X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.5794, OOF: 0.58377
#
# Train on: ['X_month_train', 'X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.56897, OOF: 0.57292
#
# Train on: ['X_month_train', 'X_dow_train', 'X_minute_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.59456, OOF: 0.59996
#
# Train on: ['X_month_train', 'X_dow_train', 'X_minute_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.59224, OOF: 0.59441
#
# Train on: ['X_month_train', 'X_dow_train', 'X_minute_train', 'X_carrier_train', 'X_route_train']
# CV: 0.58622, OOF: 0.5857
#
# Train on: ['X_month_train', 'X_dow_train', 'X_minute_train', 'X_origin_train', 'X_dest_train']
# CV: 0.59096, OOF: 0.59536
#
# Train on: ['X_month_train', 'X_dow_train', 'X_minute_train', 'X_origin_train', 'X_route_train']
# CV: 0.58138, OOF: 0.58721
#
# Train on: ['X_month_train', 'X_dow_train', 'X_minute_train', 'X_dest_train', 'X_route_train']
# CV: 0.57943, OOF: 0.58426
#
# Train on: ['X_month_train', 'X_dow_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.59371, OOF: 0.59911
#
# Train on: ['X_month_train', 'X_dow_train', 'X_isweekend_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.59273, OOF: 0.59226
#
# Train on: ['X_month_train', 'X_dow_train', 'X_isweekend_train', 'X_carrier_train', 'X_route_train']
# CV: 0.58427, OOF: 0.58412
#
# Train on: ['X_month_train', 'X_dow_train', 'X_isweekend_train', 'X_origin_train', 'X_dest_train']
# CV: 0.5906, OOF: 0.59581
#
# Train on: ['X_month_train', 'X_dow_train', 'X_isweekend_train', 'X_origin_train', 'X_route_train']
# CV: 0.58023, OOF: 0.58584
#
# ...
# CV: 0.56885, OOF: 0.57239
#
# Train on: ['X_dom_train', 'X_minute_train', 'X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.56609, OOF: 0.56453
#
# Train on: ['X_dom_train', 'X_minute_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.56676, OOF: 0.57257
#
# Train on: ['X_dom_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train']
# CV: 0.58257, OOF: 0.58328
#
# Train on: ['X_dom_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train', 'X_route_train']
# CV: 0.56808, OOF: 0.57018
#
# Train on: ['X_dom_train', 'X_isweekend_train', 'X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.56527, OOF: 0.56248
#
# Train on: ['X_dom_train', 'X_isweekend_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.56617, OOF: 0.57319
#
# Train on: ['X_dom_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.57934, OOF: 0.58492
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.68934, OOF: 0.68897
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.6884, OOF: 0.68804
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.68818, OOF: 0.68747
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.68595, OOF: 0.68312
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_minute_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.6918, OOF: 0.69118
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_minute_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.69207, OOF: 0.6909
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_minute_train', 'X_carrier_train', 'X_route_train']
# CV: 0.68912, OOF: 0.68877
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_minute_train', 'X_origin_train', 'X_dest_train']
# CV: 0.6907, OOF: 0.68803
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_minute_train', 'X_origin_train', 'X_route_train']
# CV: 0.68913, OOF: 0.68751
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_minute_train', 'X_dest_train', 'X_route_train']
# CV: 0.68906, OOF: 0.68744
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.6918, OOF: 0.69137
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.69194, OOF: 0.69079
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_carrier_train', 'X_route_train']
# CV: 0.68879, OOF: 0.68905
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_origin_train', 'X_dest_train']
# CV: 0.69097, OOF: 0.68533
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_origin_train', 'X_route_train']
# CV: 0.68942, OOF: 0.68778
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_dest_train', 'X_route_train']
# CV: 0.68831, OOF: 0.68719
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train']
# CV: 0.69425, OOF: 0.69158
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_carrier_train', 'X_origin_train', 'X_route_train']
# CV: 0.69251, OOF: 0.69114
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.6918, OOF: 0.69035
#
# Train on: ['X_dow_train', 'X_hour_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.69154, OOF: 0.68796
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.57475, OOF: 0.5812
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.57434, OOF: 0.57064
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_carrier_train', 'X_route_train']
# CV: 0.56435, OOF: 0.56271
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_origin_train', 'X_dest_train']
# CV: 0.57421, OOF: 0.58084
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_origin_train', 'X_route_train']
# CV: 0.55958, OOF: 0.56641
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_dest_train', 'X_route_train']
# CV: 0.55978, OOF: 0.56579
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train']
# CV: 0.58633, OOF: 0.59236
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_carrier_train', 'X_origin_train', 'X_route_train']
# CV: 0.57519, OOF: 0.57992
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.57596, OOF: 0.57342
#
# Train on: ['X_dow_train', 'X_minute_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.57368, OOF: 0.58108
#
# Train on: ['X_dow_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train']
# CV: 0.58551, OOF: 0.58947
#
# Train on: ['X_dow_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train', 'X_route_train']
# CV: 0.57257, OOF: 0.57812
#
# Train on: ['X_dow_train', 'X_isweekend_train', 'X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.57396, OOF: 0.57092
#
# Train on: ['X_dow_train', 'X_isweekend_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.57438, OOF: 0.57981
#
# Train on: ['X_dow_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.58501, OOF: 0.58992
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.68985, OOF: 0.68842
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.68912, OOF: 0.68782
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_carrier_train', 'X_route_train']
# CV: 0.68789, OOF: 0.68595
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_origin_train', 'X_dest_train']
# CV: 0.68753, OOF: 0.68528
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_origin_train', 'X_route_train']
# CV: 0.68692, OOF: 0.68444
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_dest_train', 'X_route_train']
# CV: 0.68586, OOF: 0.68459
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train']
# CV: 0.69054, OOF: 0.68864
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_carrier_train', 'X_origin_train', 'X_route_train']
# CV: 0.69007, OOF: 0.68832
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.68876, OOF: 0.68861
#
# Train on: ['X_hour_train', 'X_minute_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.6875, OOF: 0.68516
#
# Train on: ['X_hour_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train']
# CV: 0.6908, OOF: 0.68861
#
# Train on: ['X_hour_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train', 'X_route_train']
# CV: 0.68885, OOF: 0.68862
#
# Train on: ['X_hour_train', 'X_isweekend_train', 'X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.68855, OOF: 0.68744
#
# Train on: ['X_hour_train', 'X_isweekend_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.68737, OOF: 0.6853
#
# Train on: ['X_hour_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.69045, OOF: 0.68863
#
# Train on: ['X_minute_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train']
# CV: 0.58164, OOF: 0.58446
#
# Train on: ['X_minute_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train', 'X_route_train']
# CV: 0.56935, OOF: 0.57557
#
# Train on: ['X_minute_train', 'X_isweekend_train', 'X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.56556, OOF: 0.56489
#
# Train on: ['X_minute_train', 'X_isweekend_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.56506, OOF: 0.57113
#
# Train on: ['X_minute_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.58192, OOF: 0.58326
#
# Train on: ['X_isweekend_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.57858, OOF: 0.58429
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_minute_train', 'X_isweekend_train']
# CV: 0.69048, OOF: 0.6881
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_minute_train', 'X_carrier_train']
# CV: 0.69401, OOF: 0.69507
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_minute_train', 'X_origin_train']
# CV: 0.69368, OOF: 0.69142
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_minute_train', 'X_dest_train']
# CV: 0.69243, OOF: 0.69129
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_minute_train', 'X_route_train']
# CV: 0.69092, OOF: 0.69037
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.69418, OOF: 0.69508
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.69297, OOF: 0.69118
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.692, OOF: 0.6913
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.69062, OOF: 0.69071
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.69583, OOF: 0.69456
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.69598, OOF: 0.69196
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_carrier_train', 'X_route_train']
# CV: 0.69422, OOF: 0.69252
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_origin_train', 'X_dest_train']
# CV: 0.69377, OOF: 0.69237
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_origin_train', 'X_route_train']
# CV: 0.69335, OOF: 0.69194
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_hour_train', 'X_dest_train', 'X_route_train']
# CV: 0.69261, OOF: 0.69372
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.59177, OOF: 0.59442
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.58857, OOF: 0.59545
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.58801, OOF: 0.59261
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_minute_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.57892, OOF: 0.58348
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_minute_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.59761, OOF: 0.60482
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_minute_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.59565, OOF: 0.59937
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_minute_train', 'X_carrier_train', 'X_route_train']
# CV: 0.59025, OOF: 0.59246
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_minute_train', 'X_origin_train', 'X_dest_train']
# CV: 0.59502, OOF: 0.60264
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_minute_train', 'X_origin_train', 'X_route_train']
# CV: 0.58763, OOF: 0.59413
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_minute_train', 'X_dest_train', 'X_route_train']
# CV: 0.58658, OOF: 0.59607
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.59741, OOF: 0.60199
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_isweekend_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.59607, OOF: 0.5996
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_isweekend_train', 'X_carrier_train', 'X_route_train']
# CV: 0.59073, OOF: 0.59219
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_isweekend_train', 'X_origin_train', 'X_dest_train']
# CV: 0.59423, OOF: 0.6034
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_isweekend_train', 'X_origin_train', 'X_route_train']
# CV: 0.58843, OOF: 0.59479
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_isweekend_train', 'X_dest_train', 'X_route_train']
# CV: 0.58714, OOF: 0.59656
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train']
# CV: 0.60145, OOF: 0.60585
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_carrier_train', 'X_origin_train', 'X_route_train']
# CV: 0.59709, OOF: 0.60175
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.59487, OOF: 0.59937
#
# Train on: ['X_month_train', 'X_dom_train', 'X_dow_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.59464, OOF: 0.60198
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_carrier_train']
# CV: 0.69363, OOF: 0.69221
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_origin_train']
# CV: 0.69266, OOF: 0.69103
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_dest_train']
# CV: 0.6916, OOF: 0.69132
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_minute_train', 'X_isweekend_train', 'X_route_train']
# CV: 0.69006, OOF: 0.69016
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_minute_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.69448, OOF: 0.69408
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_minute_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.6947, OOF: 0.69476
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_minute_train', 'X_carrier_train', 'X_route_train']
# CV: 0.69432, OOF: 0.69047
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_minute_train', 'X_origin_train', 'X_dest_train']
# CV: 0.69356, OOF: 0.69213
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_minute_train', 'X_origin_train', 'X_route_train']
# CV: 0.69311, OOF: 0.69249
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_minute_train', 'X_dest_train', 'X_route_train']
# CV: 0.6911, OOF: 0.69211
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.69444, OOF: 0.69427
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_isweekend_train', 'X_carrier_train', 'X_dest_train']
# CV: 0.69545, OOF: 0.69451
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_isweekend_train', 'X_carrier_train', 'X_route_train']
# CV: 0.6941, OOF: 0.69253
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_isweekend_train', 'X_origin_train', 'X_dest_train']
# CV: 0.69328, OOF: 0.69209
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_isweekend_train', 'X_origin_train', 'X_route_train']
# CV: 0.69305, OOF: 0.69179
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_isweekend_train', 'X_dest_train', 'X_route_train']
# CV: 0.69169, OOF: 0.69205
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_carrier_train', 'X_origin_train', 'X_dest_train']
# CV: 0.69581, OOF: 0.69288
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_carrier_train', 'X_origin_train', 'X_route_train']
# CV: 0.69484, OOF: 0.69418
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_carrier_train', 'X_dest_train', 'X_route_train']
# CV: 0.69394, OOF: 0.69432
#
# Train on: ['X_month_train', 'X_dom_train', 'X_hour_train', 'X_origin_train', 'X_dest_train', 'X_route_train']
# CV: 0.69283, OOF: 0.6919
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train', 'X_isweekend_train', 'X_carrier_train', 'X_origin_train']
# CV: 0.58985, OOF: 0.59212
#
# Train on: ['X_month_train', 'X_dom_train', 'X_minute_train', 'X_isweekend_train', 'X_carrier_train', 'X_dest_train']

# %% [markdown]
# ### CONCATENATE DATA

# %%
y = target.dep_delayed_15min.values
print("Classes in dataset:", np.unique(y)) 
print('Size:', y.shape)
print("positive objects:", y.sum())
# Out:
# Classes in dataset: [0 1]
# Size: (99994,)
# positive objects: 19038

# %%
X = hstack([csr_matrix(X_month_train), 
            X_dom_train, 
            X_dow_train, 
            X_hour_train, 
            X_minute_train,
            X_isweekend_train,
            X_carrier_train,
            X_origin_train,
            X_dest_train,
            X_route_train] , format='csr')

X_test = hstack([csr_matrix(X_month_test), 
            X_dom_test, 
            X_dow_test, 
            X_hour_test, 
            X_minute_test,
            X_isweekend_test,
            X_carrier_test,
            X_origin_test,
            X_dest_test,
            X_route_test], format='csr')

X.shape, X_test.shape, y.shape
# Out:
# ((99994, 5165), (100000, 5405), (99994,))

# %% [markdown]
# ## RandomForestClassifier TRAINING

# %% [markdown]
# ### Simple Random forest

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
        X, y, train_size=0.7, random_state=42)

rf = RandomForestClassifier(n_estimators=1000, n_jobs=-1, oob_score=True)

# %%
# %%time
rf.fit(X_train, y_train)
# Out:
# CPU times: user 26min 49s, sys: 2.54 s, total: 26min 52s
# Wall time: 39.3 s
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=-1,
#             oob_score=True, random_state=None, verbose=0, warm_start=False)

# %%
rf.oob_score_
# Out:
# 0.8145438959925709

# %%
roc_auc_score(y_valid, rf.predict_proba(X_valid)[:,1])
# Out:
# 0.741062778635836

# %% [markdown]
# ### Simple catboost

# %%
from catboost import CatBoostClassifier

# %%
cat_features_idx = np.where((train.dtypes == 'object') | (train.dtypes == 'int64'))[0].tolist()

# %%
cat_features_idx
# Out:
# [0, 1, 2, 3, 4, 5, 7, 8, 9, 10]

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
        train, target, train_size=0.7, random_state=42)

# %%
cat = CatBoostClassifier(random_state=42, thread_count=72)

# %%
# %time cat.fit(X_train, y_train, cat_features=cat_features_idx)
# Out:
# 0:	learn: 0.6646956	total: 117ms	remaining: 1m 56s
# 1:	learn: 0.6370554	total: 224ms	remaining: 1m 51s
# 2:	learn: 0.6157410	total: 311ms	remaining: 1m 43s
# 3:	learn: 0.5944024	total: 405ms	remaining: 1m 40s
# 4:	learn: 0.5768418	total: 498ms	remaining: 1m 39s
# 5:	learn: 0.5606891	total: 596ms	remaining: 1m 38s
# 6:	learn: 0.5470106	total: 681ms	remaining: 1m 36s
# 7:	learn: 0.5350466	total: 776ms	remaining: 1m 36s
# 8:	learn: 0.5259466	total: 823ms	remaining: 1m 30s
# 9:	learn: 0.5185023	total: 884ms	remaining: 1m 27s
# 10:	learn: 0.5099633	total: 966ms	remaining: 1m 26s
# 11:	learn: 0.5036732	total: 1.04s	remaining: 1m 25s
# 12:	learn: 0.4962711	total: 1.12s	remaining: 1m 24s
# 13:	learn: 0.4901022	total: 1.21s	remaining: 1m 25s
# 14:	learn: 0.4847032	total: 1.29s	remaining: 1m 25s
# 15:	learn: 0.4801683	total: 1.39s	remaining: 1m 25s
# 16:	learn: 0.4763091	total: 1.48s	remaining: 1m 25s
# 17:	learn: 0.4720401	total: 1.57s	remaining: 1m 25s
# 18:	learn: 0.4682977	total: 1.68s	remaining: 1m 26s
# 19:	learn: 0.4654739	total: 1.76s	remaining: 1m 26s
# 20:	learn: 0.4627312	total: 1.86s	remaining: 1m 26s
# 21:	learn: 0.4602105	total: 1.94s	remaining: 1m 26s
# 22:	learn: 0.4579049	total: 2.04s	remaining: 1m 26s
# 23:	learn: 0.4557181	total: 2.14s	remaining: 1m 27s
# 24:	learn: 0.4540054	total: 2.23s	remaining: 1m 26s
# 25:	learn: 0.4523991	total: 2.32s	remaining: 1m 26s
# 26:	learn: 0.4505569	total: 2.4s	remaining: 1m 26s
# 27:	learn: 0.4492792	total: 2.48s	remaining: 1m 26s
# 28:	learn: 0.4471184	total: 2.56s	remaining: 1m 25s
# 29:	learn: 0.4453156	total: 2.66s	remaining: 1m 26s
# 30:	learn: 0.4440585	total: 2.76s	remaining: 1m 26s
# 31:	learn: 0.4431319	total: 2.87s	remaining: 1m 26s
# 32:	learn: 0.4418384	total: 2.96s	remaining: 1m 26s
# 33:	learn: 0.4404561	total: 3.06s	remaining: 1m 27s
# 34:	learn: 0.4397980	total: 3.17s	remaining: 1m 27s
# 35:	learn: 0.4385188	total: 3.26s	remaining: 1m 27s
# 36:	learn: 0.4373600	total: 3.34s	remaining: 1m 26s
# 37:	learn: 0.4362276	total: 3.43s	remaining: 1m 26s
# 38:	learn: 0.4353403	total: 3.53s	remaining: 1m 26s
# 39:	learn: 0.4344197	total: 3.62s	remaining: 1m 26s
# 40:	learn: 0.4335114	total: 3.72s	remaining: 1m 27s
# 41:	learn: 0.4325442	total: 3.82s	remaining: 1m 27s
# 42:	learn: 0.4316855	total: 3.91s	remaining: 1m 27s
# 180:	learn: 0.4031535	total: 16.3s	remaining: 1m 13s
# 181:	learn: 0.4031089	total: 16.3s	remaining: 1m 13s
# 182:	learn: 0.4030498	total: 16.4s	remaining: 1m 13s
# 183:	learn: 0.4029546	total: 16.5s	remaining: 1m 13s
# 184:	learn: 0.4029148	total: 16.6s	remaining: 1m 13s
# 185:	learn: 0.4028166	total: 16.7s	remaining: 1m 12s
# 186:	learn: 0.4027860	total: 16.7s	remaining: 1m 12s
# 187:	learn: 0.4027316	total: 16.8s	remaining: 1m 12s
# 188:	learn: 0.4026840	total: 16.9s	remaining: 1m 12s
# 189:	learn: 0.4026136	total: 17s	remaining: 1m 12s
# 190:	learn: 0.4025894	total: 17.1s	remaining: 1m 12s
# 191:	learn: 0.4025000	total: 17.2s	remaining: 1m 12s
# 192:	learn: 0.4024661	total: 17.3s	remaining: 1m 12s
# 193:	learn: 0.4023712	total: 17.4s	remaining: 1m 12s
# 194:	learn: 0.4023083	total: 17.5s	remaining: 1m 12s
# 195:	learn: 0.4022540	total: 17.5s	remaining: 1m 11s
# 196:	learn: 0.4021808	total: 17.6s	remaining: 1m 11s
# 197:	learn: 0.4020740	total: 17.7s	remaining: 1m 11s
# 198:	learn: 0.4020010	total: 17.8s	remaining: 1m 11s
# 199:	learn: 0.4018961	total: 17.9s	remaining: 1m 11s
# 200:	learn: 0.4018080	total: 18s	remaining: 1m 11s
# 201:	learn: 0.4017518	total: 18.1s	remaining: 1m 11s
# 202:	learn: 0.4017287	total: 18.2s	remaining: 1m 11s
# 203:	learn: 0.4016664	total: 18.3s	remaining: 1m 11s
# 204:	learn: 0.4016004	total: 18.4s	remaining: 1m 11s
# 205:	learn: 0.4015267	total: 18.4s	remaining: 1m 11s
# 206:	learn: 0.4014792	total: 18.5s	remaining: 1m 10s
# 207:	learn: 0.4014255	total: 18.6s	remaining: 1m 10s
# 208:	learn: 0.4013663	total: 18.7s	remaining: 1m 10s
# 209:	learn: 0.4013224	total: 18.8s	remaining: 1m 10s
# 210:	learn: 0.4012442	total: 18.9s	remaining: 1m 10s
# 211:	learn: 0.4011741	total: 19s	remaining: 1m 10s
# 212:	learn: 0.4011272	total: 19.1s	remaining: 1m 10s
# 213:	learn: 0.4010218	total: 19.2s	remaining: 1m 10s
# 214:	learn: 0.4009306	total: 19.3s	remaining: 1m 10s
# 215:	learn: 0.4008593	total: 19.3s	remaining: 1m 10s
# 216:	learn: 0.4007607	total: 19.4s	remaining: 1m 10s
# 217:	learn: 0.4006903	total: 19.5s	remaining: 1m 10s
# 218:	learn: 0.4006380	total: 19.6s	remaining: 1m 9s
# 219:	learn: 0.4005511	total: 19.7s	remaining: 1m 9s
# 220:	learn: 0.4005312	total: 19.8s	remaining: 1m 9s
# 221:	learn: 0.4004995	total: 19.9s	remaining: 1m 9s
# 222:	learn: 0.4004721	total: 20s	remaining: 1m 9s
# 223:	learn: 0.4004493	total: 20.1s	remaining: 1m 9s
# 224:	learn: 0.4003944	total: 20.2s	remaining: 1m 9s
# 225:	learn: 0.4003459	total: 20.3s	remaining: 1m 9s
# 226:	learn: 0.4002797	total: 20.4s	remaining: 1m 9s
# 227:	learn: 0.4001637	total: 20.5s	remaining: 1m 9s
# 228:	learn: 0.4001303	total: 20.5s	remaining: 1m 9s
# 229:	learn: 0.4000768	total: 20.6s	remaining: 1m 9s
# 230:	learn: 0.3999664	total: 20.7s	remaining: 1m 8s
# 231:	learn: 0.3999284	total: 20.8s	remaining: 1m 8s
# 232:	learn: 0.3998340	total: 20.9s	remaining: 1m 8s
# 233:	learn: 0.3997614	total: 20.9s	remaining: 1m 8s
# 234:	learn: 0.3997016	total: 21s	remaining: 1m 8s
# 235:	learn: 0.3996764	total: 21.1s	remaining: 1m 8s
# 236:	learn: 0.3995586	total: 21.2s	remaining: 1m 8s
# 237:	learn: 0.3994793	total: 21.3s	remaining: 1m 8s
# 238:	learn: 0.3993764	total: 21.4s	remaining: 1m 8s
# 239:	learn: 0.3993093	total: 21.5s	remaining: 1m 8s
# 240:	learn: 0.3992599	total: 21.6s	remaining: 1m 7s
# 241:	learn: 0.3991907	total: 21.7s	remaining: 1m 7s
# 242:	learn: 0.3991289	total: 21.8s	remaining: 1m 7s
# 243:	learn: 0.3990626	total: 21.9s	remaining: 1m 7s
# 244:	learn: 0.3990345	total: 22s	remaining: 1m 7s
# 245:	learn: 0.3989689	total: 22s	remaining: 1m 7s
# 246:	learn: 0.3989158	total: 22.1s	remaining: 1m 7s
# 247:	learn: 0.3988444	total: 22.2s	remaining: 1m 7s
# 248:	learn: 0.3987486	total: 22.3s	remaining: 1m 7s
# 249:	learn: 0.3986966	total: 22.4s	remaining: 1m 7s
# 250:	learn: 0.3986125	total: 22.5s	remaining: 1m 7s
# 251:	learn: 0.3985782	total: 22.6s	remaining: 1m 7s
# 252:	learn: 0.3985335	total: 22.7s	remaining: 1m 6s
# 253:	learn: 0.3985073	total: 22.8s	remaining: 1m 6s
# 254:	learn: 0.3984488	total: 22.9s	remaining: 1m 6s
# 255:	learn: 0.3983419	total: 22.9s	remaining: 1m 6s
# 256:	learn: 0.3982467	total: 23s	remaining: 1m 6s
# 257:	learn: 0.3982066	total: 23.1s	remaining: 1m 6s
# 258:	learn: 0.3981595	total: 23.2s	remaining: 1m 6s
# 259:	learn: 0.3981142	total: 23.3s	remaining: 1m 6s
# 260:	learn: 0.3980833	total: 23.4s	remaining: 1m 6s
# 261:	learn: 0.3980131	total: 23.5s	remaining: 1m 6s
# 262:	learn: 0.3979602	total: 23.6s	remaining: 1m 6s
# 263:	learn: 0.3979074	total: 23.7s	remaining: 1m 5s
# 264:	learn: 0.3978450	total: 23.7s	remaining: 1m 5s
# 265:	learn: 0.3977842	total: 23.8s	remaining: 1m 5s
# 266:	learn: 0.3977130	total: 23.9s	remaining: 1m 5s
# 267:	learn: 0.3976178	total: 24s	remaining: 1m 5s
# 268:	learn: 0.3975346	total: 24.1s	remaining: 1m 5s
# 269:	learn: 0.3974622	total: 24.2s	remaining: 1m 5s
# 270:	learn: 0.3974156	total: 24.3s	remaining: 1m 5s
# 271:	learn: 0.3973873	total: 24.4s	remaining: 1m 5s
# 272:	learn: 0.3973294	total: 24.5s	remaining: 1m 5s
# 273:	learn: 0.3972570	total: 24.6s	remaining: 1m 5s
# 274:	learn: 0.3972008	total: 24.7s	remaining: 1m 5s
# 275:	learn: 0.3971650	total: 24.8s	remaining: 1m 5s
# 276:	learn: 0.3971008	total: 24.9s	remaining: 1m 4s
# 277:	learn: 0.3970519	total: 25s	remaining: 1m 4s
# 278:	learn: 0.3970209	total: 25.1s	remaining: 1m 4s
# 279:	learn: 0.3969892	total: 25.2s	remaining: 1m 4s
# 280:	learn: 0.3969306	total: 25.2s	remaining: 1m 4s
# 281:	learn: 0.3969045	total: 25.3s	remaining: 1m 4s
# 282:	learn: 0.3968541	total: 25.4s	remaining: 1m 4s
# 283:	learn: 0.3968163	total: 25.5s	remaining: 1m 4s
# 284:	learn: 0.3967759	total: 25.6s	remaining: 1m 4s
# 285:	learn: 0.3967411	total: 25.7s	remaining: 1m 4s
# 286:	learn: 0.3967039	total: 25.8s	remaining: 1m 4s
# 287:	learn: 0.3966649	total: 25.9s	remaining: 1m 3s
# 288:	learn: 0.3966240	total: 26s	remaining: 1m 3s
# 289:	learn: 0.3965528	total: 26s	remaining: 1m 3s
# 290:	learn: 0.3965023	total: 26.1s	remaining: 1m 3s
# 291:	learn: 0.3964234	total: 26.2s	remaining: 1m 3s
# 292:	learn: 0.3963565	total: 26.3s	remaining: 1m 3s
# 293:	learn: 0.3963307	total: 26.4s	remaining: 1m 3s
# 294:	learn: 0.3962806	total: 26.5s	remaining: 1m 3s
# 295:	learn: 0.3962197	total: 26.6s	remaining: 1m 3s
# 296:	learn: 0.3961783	total: 26.7s	remaining: 1m 3s
# 297:	learn: 0.3961543	total: 26.7s	remaining: 1m 3s
# 298:	learn: 0.3960894	total: 26.8s	remaining: 1m 2s
# 299:	learn: 0.3960295	total: 26.9s	remaining: 1m 2s
# 300:	learn: 0.3959954	total: 27s	remaining: 1m 2s
# 301:	learn: 0.3959413	total: 27.1s	remaining: 1m 2s
# 302:	learn: 0.3958255	total: 27.2s	remaining: 1m 2s
# 303:	learn: 0.3957751	total: 27.3s	remaining: 1m 2s
# 304:	learn: 0.3957230	total: 27.4s	remaining: 1m 2s
# 305:	learn: 0.3957027	total: 27.5s	remaining: 1m 2s
# 306:	learn: 0.3956548	total: 27.6s	remaining: 1m 2s
# 307:	learn: 0.3956064	total: 27.7s	remaining: 1m 2s
# 308:	learn: 0.3955614	total: 27.8s	remaining: 1m 2s
# 309:	learn: 0.3954572	total: 27.9s	remaining: 1m 2s
# 310:	learn: 0.3954122	total: 28s	remaining: 1m 1s
# 311:	learn: 0.3953611	total: 28.1s	remaining: 1m 1s
# 312:	learn: 0.3953071	total: 28.2s	remaining: 1m 1s
# 313:	learn: 0.3951729	total: 28.2s	remaining: 1m 1s
# 314:	learn: 0.3951453	total: 28.3s	remaining: 1m 1s
# 315:	learn: 0.3950964	total: 28.4s	remaining: 1m 1s
# 316:	learn: 0.3950308	total: 28.5s	remaining: 1m 1s
# 650:	learn: 0.3818291	total: 1m	remaining: 32.5s
# 651:	learn: 0.3817789	total: 1m	remaining: 32.4s
# 652:	learn: 0.3817403	total: 1m	remaining: 32.3s
# 653:	learn: 0.3817161	total: 1m	remaining: 32.2s
# 654:	learn: 0.3816451	total: 1m	remaining: 32.1s
# 655:	learn: 0.3815980	total: 1m 1s	remaining: 32s
# 656:	learn: 0.3815691	total: 1m 1s	remaining: 31.9s
# 657:	learn: 0.3815075	total: 1m 1s	remaining: 31.8s
# 658:	learn: 0.3814645	total: 1m 1s	remaining: 31.7s
# 659:	learn: 0.3814372	total: 1m 1s	remaining: 31.7s
# 660:	learn: 0.3813864	total: 1m 1s	remaining: 31.6s
# 661:	learn: 0.3813436	total: 1m 1s	remaining: 31.5s
# 662:	learn: 0.3812922	total: 1m 1s	remaining: 31.4s
# 663:	learn: 0.3812517	total: 1m 1s	remaining: 31.3s
# 664:	learn: 0.3812062	total: 1m 1s	remaining: 31.2s
# 665:	learn: 0.3811591	total: 1m 2s	remaining: 31.1s
# 666:	learn: 0.3811167	total: 1m 2s	remaining: 31s
# 667:	learn: 0.3811004	total: 1m 2s	remaining: 30.9s
# 668:	learn: 0.3810727	total: 1m 2s	remaining: 30.8s
# 669:	learn: 0.3810030	total: 1m 2s	remaining: 30.8s
# 670:	learn: 0.3809619	total: 1m 2s	remaining: 30.7s
# 671:	learn: 0.3809485	total: 1m 2s	remaining: 30.6s
# 672:	learn: 0.3809226	total: 1m 2s	remaining: 30.5s
# 673:	learn: 0.3808957	total: 1m 2s	remaining: 30.4s
# 674:	learn: 0.3808699	total: 1m 2s	remaining: 30.3s
# 675:	learn: 0.3808556	total: 1m 3s	remaining: 30.2s
# 676:	learn: 0.3808058	total: 1m 3s	remaining: 30.1s
# 677:	learn: 0.3807528	total: 1m 3s	remaining: 30s
# 678:	learn: 0.3806956	total: 1m 3s	remaining: 29.9s
# 679:	learn: 0.3806415	total: 1m 3s	remaining: 29.9s
# 680:	learn: 0.3805724	total: 1m 3s	remaining: 29.8s
# 681:	learn: 0.3804815	total: 1m 3s	remaining: 29.7s
# 682:	learn: 0.3804518	total: 1m 3s	remaining: 29.6s
# 683:	learn: 0.3804274	total: 1m 3s	remaining: 29.5s
# 684:	learn: 0.3804078	total: 1m 3s	remaining: 29.4s
# 685:	learn: 0.3803599	total: 1m 4s	remaining: 29.3s
# 686:	learn: 0.3803210	total: 1m 4s	remaining: 29.2s
# 687:	learn: 0.3802726	total: 1m 4s	remaining: 29.1s
# 688:	learn: 0.3802255	total: 1m 4s	remaining: 29s
# 689:	learn: 0.3801746	total: 1m 4s	remaining: 28.9s
# 690:	learn: 0.3800539	total: 1m 4s	remaining: 28.8s
# 691:	learn: 0.3800246	total: 1m 4s	remaining: 28.7s
# 692:	learn: 0.3799947	total: 1m 4s	remaining: 28.6s
# 693:	learn: 0.3799639	total: 1m 4s	remaining: 28.5s
# 694:	learn: 0.3799197	total: 1m 4s	remaining: 28.4s
# 695:	learn: 0.3798765	total: 1m 4s	remaining: 28.3s
# 696:	learn: 0.3798252	total: 1m 5s	remaining: 28.3s
# 697:	learn: 0.3797849	total: 1m 5s	remaining: 28.2s
# 698:	learn: 0.3797642	total: 1m 5s	remaining: 28.1s
# 699:	learn: 0.3797350	total: 1m 5s	remaining: 28s
# 700:	learn: 0.3796924	total: 1m 5s	remaining: 27.9s
# 701:	learn: 0.3796571	total: 1m 5s	remaining: 27.8s
# 702:	learn: 0.3796229	total: 1m 5s	remaining: 27.7s
# 703:	learn: 0.3795782	total: 1m 5s	remaining: 27.6s
# 704:	learn: 0.3795478	total: 1m 5s	remaining: 27.5s
# 705:	learn: 0.3795311	total: 1m 5s	remaining: 27.4s
# 706:	learn: 0.3795043	total: 1m 6s	remaining: 27.4s
# 707:	learn: 0.3794781	total: 1m 6s	remaining: 27.3s
# 708:	learn: 0.3794449	total: 1m 6s	remaining: 27.2s
# 709:	learn: 0.3794089	total: 1m 6s	remaining: 27.1s
# 710:	learn: 0.3793926	total: 1m 6s	remaining: 27s
# 711:	learn: 0.3793088	total: 1m 6s	remaining: 26.9s
# 712:	learn: 0.3792736	total: 1m 6s	remaining: 26.8s
# 713:	learn: 0.3792377	total: 1m 6s	remaining: 26.7s
# 714:	learn: 0.3792109	total: 1m 6s	remaining: 26.6s
# 715:	learn: 0.3791829	total: 1m 6s	remaining: 26.5s
# 716:	learn: 0.3791489	total: 1m 6s	remaining: 26.4s
# 717:	learn: 0.3790931	total: 1m 7s	remaining: 26.3s
# 718:	learn: 0.3790415	total: 1m 7s	remaining: 26.3s
# 719:	learn: 0.3789933	total: 1m 7s	remaining: 26.2s
# 720:	learn: 0.3789394	total: 1m 7s	remaining: 26.1s
# 721:	learn: 0.3788782	total: 1m 7s	remaining: 26s
# 722:	learn: 0.3788458	total: 1m 7s	remaining: 25.9s
# 723:	learn: 0.3788168	total: 1m 7s	remaining: 25.8s
# 724:	learn: 0.3787864	total: 1m 7s	remaining: 25.7s
# 725:	learn: 0.3787585	total: 1m 7s	remaining: 25.6s
# 726:	learn: 0.3787287	total: 1m 8s	remaining: 25.5s
# 727:	learn: 0.3786935	total: 1m 8s	remaining: 25.4s
# 728:	learn: 0.3786587	total: 1m 8s	remaining: 25.4s
# 729:	learn: 0.3786196	total: 1m 8s	remaining: 25.3s
# 730:	learn: 0.3785901	total: 1m 8s	remaining: 25.2s
# 731:	learn: 0.3785626	total: 1m 8s	remaining: 25.1s
# 732:	learn: 0.3785320	total: 1m 8s	remaining: 25s
# 733:	learn: 0.3784674	total: 1m 8s	remaining: 24.9s
# 734:	learn: 0.3784445	total: 1m 8s	remaining: 24.8s
# 735:	learn: 0.3784209	total: 1m 8s	remaining: 24.7s
# 736:	learn: 0.3783954	total: 1m 8s	remaining: 24.6s
# 737:	learn: 0.3783734	total: 1m 9s	remaining: 24.5s
# 738:	learn: 0.3783048	total: 1m 9s	remaining: 24.4s
# 739:	learn: 0.3782749	total: 1m 9s	remaining: 24.3s
# 740:	learn: 0.3782567	total: 1m 9s	remaining: 24.2s
# 741:	learn: 0.3781934	total: 1m 9s	remaining: 24.1s
# 742:	learn: 0.3781576	total: 1m 9s	remaining: 24.1s
# 743:	learn: 0.3781228	total: 1m 9s	remaining: 24s
# 744:	learn: 0.3780693	total: 1m 9s	remaining: 23.9s
# 745:	learn: 0.3780531	total: 1m 9s	remaining: 23.8s
# 746:	learn: 0.3780147	total: 1m 9s	remaining: 23.7s
# 747:	learn: 0.3779849	total: 1m 10s	remaining: 23.6s
# 748:	learn: 0.3779047	total: 1m 10s	remaining: 23.5s
# 749:	learn: 0.3778640	total: 1m 10s	remaining: 23.4s
# 750:	learn: 0.3778227	total: 1m 10s	remaining: 23.3s
# 751:	learn: 0.3778021	total: 1m 10s	remaining: 23.2s
# 752:	learn: 0.3777791	total: 1m 10s	remaining: 23.1s
# 753:	learn: 0.3777462	total: 1m 10s	remaining: 23s
# 754:	learn: 0.3777001	total: 1m 10s	remaining: 23s
# 755:	learn: 0.3776620	total: 1m 10s	remaining: 22.9s
# 756:	learn: 0.3776014	total: 1m 10s	remaining: 22.8s
# 757:	learn: 0.3775837	total: 1m 11s	remaining: 22.7s
# 758:	learn: 0.3775329	total: 1m 11s	remaining: 22.6s
# 759:	learn: 0.3775175	total: 1m 11s	remaining: 22.5s
# 760:	learn: 0.3774990	total: 1m 11s	remaining: 22.4s
# 761:	learn: 0.3774625	total: 1m 11s	remaining: 22.3s
# 762:	learn: 0.3774263	total: 1m 11s	remaining: 22.2s
# 763:	learn: 0.3773903	total: 1m 11s	remaining: 22.1s
# 764:	learn: 0.3773397	total: 1m 11s	remaining: 22s
# 765:	learn: 0.3773004	total: 1m 11s	remaining: 21.9s
# 766:	learn: 0.3772750	total: 1m 11s	remaining: 21.8s
# 767:	learn: 0.3772674	total: 1m 11s	remaining: 21.7s
# 768:	learn: 0.3772400	total: 1m 12s	remaining: 21.7s
# 769:	learn: 0.3771992	total: 1m 12s	remaining: 21.6s
# 770:	learn: 0.3771722	total: 1m 12s	remaining: 21.5s
# 771:	learn: 0.3771322	total: 1m 12s	remaining: 21.4s
# 772:	learn: 0.3770956	total: 1m 12s	remaining: 21.3s
# 773:	learn: 0.3770730	total: 1m 12s	remaining: 21.2s
# 774:	learn: 0.3770457	total: 1m 12s	remaining: 21.1s
# 775:	learn: 0.3770113	total: 1m 12s	remaining: 21s
# 776:	learn: 0.3769955	total: 1m 12s	remaining: 20.9s
# 777:	learn: 0.3769604	total: 1m 12s	remaining: 20.8s
# 778:	learn: 0.3769303	total: 1m 13s	remaining: 20.7s
# 779:	learn: 0.3768979	total: 1m 13s	remaining: 20.6s
# 780:	learn: 0.3768802	total: 1m 13s	remaining: 20.5s
# 781:	learn: 0.3768331	total: 1m 13s	remaining: 20.4s
# 782:	learn: 0.3768102	total: 1m 13s	remaining: 20.3s
# 783:	learn: 0.3767546	total: 1m 13s	remaining: 20.3s
# 784:	learn: 0.3767024	total: 1m 13s	remaining: 20.2s
# 785:	learn: 0.3766571	total: 1m 13s	remaining: 20.1s
# 786:	learn: 0.3766283	total: 1m 13s	remaining: 20s
# 787:	learn: 0.3765862	total: 1m 13s	remaining: 19.9s
# 788:	learn: 0.3765392	total: 1m 13s	remaining: 19.8s
# 789:	learn: 0.3765011	total: 1m 14s	remaining: 19.7s
# 790:	learn: 0.3764733	total: 1m 14s	remaining: 19.6s
# 791:	learn: 0.3764451	total: 1m 14s	remaining: 19.5s
# 792:	learn: 0.3764000	total: 1m 14s	remaining: 19.4s
# 793:	learn: 0.3763689	total: 1m 14s	remaining: 19.3s
# 794:	learn: 0.3763437	total: 1m 14s	remaining: 19.2s
# 795:	learn: 0.3762854	total: 1m 14s	remaining: 19.1s
# 796:	learn: 0.3762284	total: 1m 14s	remaining: 19s
# 797:	learn: 0.3761790	total: 1m 14s	remaining: 18.9s
# 798:	learn: 0.3761494	total: 1m 14s	remaining: 18.9s
# 799:	learn: 0.3761189	total: 1m 15s	remaining: 18.8s
# 800:	learn: 0.3760898	total: 1m 15s	remaining: 18.7s
# 801:	learn: 0.3760618	total: 1m 15s	remaining: 18.6s
# 802:	learn: 0.3760293	total: 1m 15s	remaining: 18.5s
# 803:	learn: 0.3760004	total: 1m 15s	remaining: 18.4s
# 804:	learn: 0.3759652	total: 1m 15s	remaining: 18.3s
# 805:	learn: 0.3759112	total: 1m 15s	remaining: 18.2s
# 806:	learn: 0.3758669	total: 1m 15s	remaining: 18.1s
# 807:	learn: 0.3758370	total: 1m 15s	remaining: 18s
# 808:	learn: 0.3758199	total: 1m 15s	remaining: 17.9s
# 809:	learn: 0.3758101	total: 1m 16s	remaining: 17.8s
# 810:	learn: 0.3757997	total: 1m 16s	remaining: 17.7s
# 811:	learn: 0.3757787	total: 1m 16s	remaining: 17.7s
# 812:	learn: 0.3757475	total: 1m 16s	remaining: 17.6s
# 813:	learn: 0.3757228	total: 1m 16s	remaining: 17.5s
# 814:	learn: 0.3757064	total: 1m 16s	remaining: 17.4s
# 815:	learn: 0.3756915	total: 1m 16s	remaining: 17.3s
# 816:	learn: 0.3756327	total: 1m 16s	remaining: 17.2s
# 817:	learn: 0.3755839	total: 1m 16s	remaining: 17.1s
# 818:	learn: 0.3755668	total: 1m 16s	remaining: 17s
# 819:	learn: 0.3755346	total: 1m 16s	remaining: 16.9s
# 820:	learn: 0.3755006	total: 1m 17s	remaining: 16.8s
# 821:	learn: 0.3754450	total: 1m 17s	remaining: 16.7s
# 822:	learn: 0.3753860	total: 1m 17s	remaining: 16.6s
# 823:	learn: 0.3753609	total: 1m 17s	remaining: 16.5s
# 824:	learn: 0.3753223	total: 1m 17s	remaining: 16.4s
# 825:	learn: 0.3752874	total: 1m 17s	remaining: 16.3s
# 826:	learn: 0.3752361	total: 1m 17s	remaining: 16.2s
# 827:	learn: 0.3752213	total: 1m 17s	remaining: 16.2s
# 828:	learn: 0.3752085	total: 1m 17s	remaining: 16.1s
# 829:	learn: 0.3751569	total: 1m 17s	remaining: 16s
# 830:	learn: 0.3751362	total: 1m 18s	remaining: 15.9s
# 831:	learn: 0.3751117	total: 1m 18s	remaining: 15.8s
# 832:	learn: 0.3750731	total: 1m 18s	remaining: 15.7s
# 879:	learn: 0.3736528	total: 1m 22s	remaining: 11.2s
# 880:	learn: 0.3736327	total: 1m 22s	remaining: 11.2s
# 881:	learn: 0.3736009	total: 1m 22s	remaining: 11.1s
# 882:	learn: 0.3735492	total: 1m 22s	remaining: 11s
# 883:	learn: 0.3735305	total: 1m 22s	remaining: 10.9s
# 884:	learn: 0.3734856	total: 1m 22s	remaining: 10.8s
# 885:	learn: 0.3734598	total: 1m 23s	remaining: 10.7s
# 886:	learn: 0.3734129	total: 1m 23s	remaining: 10.6s
# 887:	learn: 0.3733878	total: 1m 23s	remaining: 10.5s
# 888:	learn: 0.3733555	total: 1m 23s	remaining: 10.4s
# 889:	learn: 0.3733242	total: 1m 23s	remaining: 10.3s
# 890:	learn: 0.3732981	total: 1m 23s	remaining: 10.2s
# 891:	learn: 0.3732387	total: 1m 23s	remaining: 10.1s
# 892:	learn: 0.3732196	total: 1m 23s	remaining: 10s
# 893:	learn: 0.3732023	total: 1m 23s	remaining: 9.94s
# 894:	learn: 0.3731847	total: 1m 23s	remaining: 9.85s
# 895:	learn: 0.3731462	total: 1m 24s	remaining: 9.76s
# 896:	learn: 0.3731184	total: 1m 24s	remaining: 9.66s
# 897:	learn: 0.3730787	total: 1m 24s	remaining: 9.57s
# 898:	learn: 0.3730277	total: 1m 24s	remaining: 9.48s
# 899:	learn: 0.3729854	total: 1m 24s	remaining: 9.39s
# 900:	learn: 0.3729757	total: 1m 24s	remaining: 9.29s
# 901:	learn: 0.3729256	total: 1m 24s	remaining: 9.2s
# 902:	learn: 0.3729132	total: 1m 24s	remaining: 9.1s
# 903:	learn: 0.3728905	total: 1m 24s	remaining: 9.01s
# 904:	learn: 0.3728597	total: 1m 24s	remaining: 8.91s
# 905:	learn: 0.3728359	total: 1m 25s	remaining: 8.82s
# 906:	learn: 0.3728179	total: 1m 25s	remaining: 8.73s
# 907:	learn: 0.3728044	total: 1m 25s	remaining: 8.63s
# 908:	learn: 0.3727838	total: 1m 25s	remaining: 8.54s
# 909:	learn: 0.3727530	total: 1m 25s	remaining: 8.44s
# 910:	learn: 0.3727296	total: 1m 25s	remaining: 8.35s
# 911:	learn: 0.3727059	total: 1m 25s	remaining: 8.25s
# 912:	learn: 0.3726512	total: 1m 25s	remaining: 8.16s
# 913:	learn: 0.3726297	total: 1m 25s	remaining: 8.06s
# 914:	learn: 0.3726084	total: 1m 25s	remaining: 7.97s
# 915:	learn: 0.3725538	total: 1m 25s	remaining: 7.88s
# 916:	learn: 0.3725121	total: 1m 26s	remaining: 7.78s
# 917:	learn: 0.3724792	total: 1m 26s	remaining: 7.69s
# 918:	learn: 0.3724494	total: 1m 26s	remaining: 7.6s
# 919:	learn: 0.3724298	total: 1m 26s	remaining: 7.5s
# 920:	learn: 0.3723916	total: 1m 26s	remaining: 7.41s
# 921:	learn: 0.3723648	total: 1m 26s	remaining: 7.32s
# 922:	learn: 0.3723389	total: 1m 26s	remaining: 7.22s
# 923:	learn: 0.3723136	total: 1m 26s	remaining: 7.13s
# 924:	learn: 0.3722840	total: 1m 26s	remaining: 7.04s
# 925:	learn: 0.3722654	total: 1m 26s	remaining: 6.94s
# 926:	learn: 0.3722303	total: 1m 26s	remaining: 6.85s
# 927:	learn: 0.3722103	total: 1m 27s	remaining: 6.76s
# 928:	learn: 0.3721899	total: 1m 27s	remaining: 6.66s
# 929:	learn: 0.3721634	total: 1m 27s	remaining: 6.57s
# 930:	learn: 0.3721426	total: 1m 27s	remaining: 6.47s
# 931:	learn: 0.3720914	total: 1m 27s	remaining: 6.38s
# 932:	learn: 0.3720501	total: 1m 27s	remaining: 6.29s
# 933:	learn: 0.3720242	total: 1m 27s	remaining: 6.2s
# 934:	learn: 0.3719845	total: 1m 27s	remaining: 6.1s
# 935:	learn: 0.3719599	total: 1m 27s	remaining: 6.01s
# 936:	learn: 0.3719363	total: 1m 27s	remaining: 5.91s
# 937:	learn: 0.3719113	total: 1m 28s	remaining: 5.82s
# 938:	learn: 0.3718907	total: 1m 28s	remaining: 5.73s
# 939:	learn: 0.3718660	total: 1m 28s	remaining: 5.63s
# 940:	learn: 0.3718261	total: 1m 28s	remaining: 5.54s
# 941:	learn: 0.3717853	total: 1m 28s	remaining: 5.44s
# 942:	learn: 0.3717421	total: 1m 28s	remaining: 5.35s
# 943:	learn: 0.3716952	total: 1m 28s	remaining: 5.26s
# 944:	learn: 0.3716755	total: 1m 28s	remaining: 5.16s
# 945:	learn: 0.3716446	total: 1m 28s	remaining: 5.07s
# 946:	learn: 0.3715874	total: 1m 28s	remaining: 4.98s
# 947:	learn: 0.3715467	total: 1m 29s	remaining: 4.88s
# 948:	learn: 0.3715273	total: 1m 29s	remaining: 4.79s
# 949:	learn: 0.3714314	total: 1m 29s	remaining: 4.7s
# 950:	learn: 0.3713972	total: 1m 29s	remaining: 4.6s
# 951:	learn: 0.3713480	total: 1m 29s	remaining: 4.51s
# 952:	learn: 0.3713270	total: 1m 29s	remaining: 4.41s
# 953:	learn: 0.3712993	total: 1m 29s	remaining: 4.32s
# 954:	learn: 0.3712662	total: 1m 29s	remaining: 4.23s
# 955:	learn: 0.3712270	total: 1m 29s	remaining: 4.13s
# 956:	learn: 0.3711848	total: 1m 29s	remaining: 4.04s
# 957:	learn: 0.3711498	total: 1m 30s	remaining: 3.95s
# 958:	learn: 0.3711323	total: 1m 30s	remaining: 3.85s
# 959:	learn: 0.3711026	total: 1m 30s	remaining: 3.76s
# 960:	learn: 0.3710742	total: 1m 30s	remaining: 3.67s
# 961:	learn: 0.3710578	total: 1m 30s	remaining: 3.57s
# 962:	learn: 0.3710261	total: 1m 30s	remaining: 3.48s
# 963:	learn: 0.3710037	total: 1m 30s	remaining: 3.38s
# 964:	learn: 0.3709685	total: 1m 30s	remaining: 3.29s
# 965:	learn: 0.3709210	total: 1m 30s	remaining: 3.19s
# 966:	learn: 0.3709041	total: 1m 30s	remaining: 3.1s
# 967:	learn: 0.3708730	total: 1m 31s	remaining: 3.01s
# 968:	learn: 0.3708277	total: 1m 31s	remaining: 2.91s
# 969:	learn: 0.3707728	total: 1m 31s	remaining: 2.82s
# 970:	learn: 0.3707444	total: 1m 31s	remaining: 2.73s
# 971:	learn: 0.3707032	total: 1m 31s	remaining: 2.63s
# 972:	learn: 0.3706900	total: 1m 31s	remaining: 2.54s
# 973:	learn: 0.3706548	total: 1m 31s	remaining: 2.44s
# 974:	learn: 0.3706290	total: 1m 31s	remaining: 2.35s
# 975:	learn: 0.3705610	total: 1m 31s	remaining: 2.26s
# 976:	learn: 0.3705399	total: 1m 31s	remaining: 2.16s
# 977:	learn: 0.3705138	total: 1m 31s	remaining: 2.07s
# 978:	learn: 0.3704828	total: 1m 32s	remaining: 1.98s
# 979:	learn: 0.3704704	total: 1m 32s	remaining: 1.88s
# 980:	learn: 0.3704209	total: 1m 32s	remaining: 1.79s
# 981:	learn: 0.3704094	total: 1m 32s	remaining: 1.69s
# 982:	learn: 0.3703538	total: 1m 32s	remaining: 1.6s
# 983:	learn: 0.3703073	total: 1m 32s	remaining: 1.5s
# 984:	learn: 0.3702852	total: 1m 32s	remaining: 1.41s
# 985:	learn: 0.3702617	total: 1m 32s	remaining: 1.32s
# 986:	learn: 0.3702304	total: 1m 32s	remaining: 1.22s
# 987:	learn: 0.3702071	total: 1m 32s	remaining: 1.13s
# 988:	learn: 0.3701689	total: 1m 33s	remaining: 1.03s
# 989:	learn: 0.3701345	total: 1m 33s	remaining: 942ms
# 990:	learn: 0.3701121	total: 1m 33s	remaining: 847ms
# 991:	learn: 0.3700823	total: 1m 33s	remaining: 753ms
# 992:	learn: 0.3700575	total: 1m 33s	remaining: 659ms
# 993:	learn: 0.3700294	total: 1m 33s	remaining: 565ms
# 994:	learn: 0.3699967	total: 1m 33s	remaining: 471ms
# 995:	learn: 0.3699599	total: 1m 33s	remaining: 377ms
# 996:	learn: 0.3699358	total: 1m 33s	remaining: 283ms
# 997:	learn: 0.3698938	total: 1m 34s	remaining: 188ms
# 998:	learn: 0.3698626	total: 1m 34s	remaining: 94.2ms
# 999:	learn: 0.3698249	total: 1m 34s	remaining: 0us
# CPU times: user 1h 43min 45s, sys: 1min 9s, total: 1h 44min 55s
# Wall time: 1min 35s

# %%
roc_auc_score(y_valid, cat.predict_proba(X_valid)[:,1])
# Out:
# 0.783345262611359

# %%
final_pred = predicts = cat.predict_proba(test)[:, 1]

# %% [markdown]
# ## Submit

# %%
# Function for writing predictions to a file
def write_to_submission_file(predicted_labels, out_file, 
                             target='dep_delayed_15min', index_label="id"):
    
    predicted_df = pd.DataFrame(
        predicted_labels,
        index = np.arange(0, predicted_labels.shape[0]),
        columns=[target])
    
    predicted_df.to_csv(out_file, index_label=index_label)

# %%
from datetime import datetime as dt
import subprocess
now = dt.now().strftime("%Y-%m-%d_%H-%M-%S")
label = subprocess.check_output(["git", "describe", "--always"]).strip().decode("utf-8")

### WRITE SUBMISSION
write_to_submission_file(final_pred, f'../submissions/catboost_submission_at_{now}__githash_{label}.csv')

pd.Series(final_pred, 
          name='dep_delayed_15min').to_csv('xgb_2feat.csv', 
                                           index_label='id', header=True)

# %%
pd.Series(final_pred, 
          name='dep_delayed_15min').to_csv('xgb_2feat.csv', 
                                           index_label='id', header=True)
